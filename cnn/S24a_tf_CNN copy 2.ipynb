# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Convolutional Neural Network
# ### Fashion MNIST Dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from collections.abc import Callable
from typing import Literal
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import tensorflow as tf 

# %matplotlib inline
# Out:
# 2023-12-15 14:39:25.706223: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-15 14:39:25.824524: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-15 14:39:25.824566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-15 14:39:25.827472: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-15 14:39:25.848679: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-15 14:39:32.037682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# gpus = tf.config.list_physical_devices('GPU')

# try:
#     for g in gpus:
#         tf.config.experimental.set_memory_growth(g, True)
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print (len(gpus), 'Phusical GPUs', len(logical_gpus), 'Logical GPUs')
# except:
#     print ('invalid device')

# %%
###----------------
### Some parameters
###----------------

inpDir = '../../input'
outDir = '../output'
subDir = 'flower_photos'
modelDir = '.../models'
altname= 'cc_base'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results

TEST_SIZE = 0.2
EPOCHS = 150 # number of epochs
ALPHA = 0.0005 # learning rate
TEST_SIZE = 0.2
BATCH_SIZE = 32
LR_PATIENCE = 10
FACTOR_LR = 0.5
TRAIN_SIZE = 256 # fix size of train set sot that we have batches of same size
PATIENCE = 15

IMG_HEIGHT = 190
IMG_WIDTH = 190

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
def fn_plot_label(train_ds , test_ds):
    
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,2,1)

    train_labels = tf.concat([lbl for img, lbl in train_ds], axis=0).numpy()

    unique, _, counts = tf.unique_with_counts(train_labels)

    plt.bar(range(len(unique)), counts, align='center', color = 'DarkBlue')

    plt.xticks(range(len(unique)), class_names)

    plt.title('training set')

    plt.subplot(1,2,2)

    test_labels = tf.concat([lbl for img, lbl in test_ds], axis=0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color = 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('testing set')

# %% [markdown]
# ## Generate Data Set
# Flower Dataset

# %%
class_label = {0 : 'Daisy',
               1 : 'Dandelion',
               2 : 'Roses',
               3 : 'Sunflowers',
               4 : 'Tupils',
               }

# %%
data_dir = os.path.join(inpDir, subDir)
data_dir
# Out:
# '../../input/flower_photos'

# %%
os.listdir(data_dir)
# Out:
# ['sunflowers', 'LICENSE.txt', 'tulips', 'dandelion', 'roses', 'daisy']

# %%
## DATASET for training

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = TEST_SIZE,
    subset = 'training',
    seed = RANDOM_STATE,
    image_size= [IMG_HEIGHT, IMG_WIDTH],
    batch_size= BATCH_SIZE
)

## DATASET for testing

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = TEST_SIZE,
    subset = 'validation',
    seed = RANDOM_STATE,
    image_size= [IMG_HEIGHT, IMG_WIDTH],
    batch_size= BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, labels in train_ds.take(1):
    for i in range(BATCH_SIZE):
        plt.subplot(int(BATCH_SIZE/8),8, i+1)
        plt.grid(False)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.axis('off')
        plt.title(class_names[labels[i]])
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,6))

for images, labels in test_ds.take(1):
    for i in range(BATCH_SIZE):
        plt.subplot(int(BATCH_SIZE/8),8, i+1)
        plt.grid(False)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.axis('off')
        plt.title(class_names[labels[i]])
    plt.tight_layout()
plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ## Random Zoom

# %%
layer = tf.keras.layers.RandomZoom(height_factor = (-0.2, -0.2),
                                   width_factor = (-0.2, -0.2))
plt.figure()
img_num = 3

for images, labels in test_ds.take(1):
    out_images = layer(images)

    plt.subplot(1,2,1)
    plt.title('Original')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1,2,2)
    plt.title('Zoomed')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
layer = tf.keras.layers.RandomRotation(
    factor=(-0.2, 0.2),
    fill_mode='reflect',
    interpolation='bilinear',
    fill_value=0.0,
)
plt.figure()
img_num = 3

for images, labels in test_ds.take(1):
    out_images = layer(images)

    plt.subplot(1,2,1)
    plt.title('Original')
    plt.imshow(images[img_num].numpy().astype('uint8'))

    plt.subplot(1,2,2)
    plt.title('Rotated')
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(factor=(-0.2, 0.3), fill_mode='reflect',
                                interpolation='bilinear', fill_value=0.0,),
  # tf.keras.layers.RandomRotation(factor=(-0.6, 0.6), fill_mode='reflect',
  #                                interpolation='bilinear', fill_value=0.0,),
  # tf.keras.layers.RandomBrightness(factor=(-1,1), value_range=(0, 255)),
  # tf.keras.layers.RandomZoom(height_factor = (-0.2, -0.2),
  #                                  width_factor = (-0.2, -0.2)),
  # tf.keras.layers.RandomContrast(
  #   factor=(0, 0.5)),
  # tf.keras.layers.RandomTranslation(
  #   height_factor = (-0.3, 0.3),
  #   width_factor = (-0.3, 0.3),
  #   fill_mode='reflect',
  #   interpolation='bilinear',
  #   seed=None,
  #   fill_value=0.0)

])

# %%
#Model

model= tf.keras.Sequential()

model.add(tf.keras.layers.Rescaling(1/255.))

model.add(data_augmentation)

##set 1
model.add(tf.keras.layers.Conv2D(8, (3,3), activation='relu'))

model.add(tf.keras.layers.MaxPool2D(2,2))  # 94 X 94 X 8


#model.add(tf.keras.layers.Dropout(0.25))

##set 2
model.add(tf.keras.layers.Conv2D(16, (3,3), activation='relu'))

model.add(tf.keras.layers.Dropout(0.01))


model.add(tf.keras.layers.MaxPool2D(2,2))  # 4 X 4 X 16

#model.add(tf.keras.layers.Dropout(0.25))

##set 3
model.add(tf.keras.layers.Conv2D(32, (3,3), activation='relu'))

model.add(tf.keras.layers.MaxPool2D(2,2))  # 4 X 4 X 32

#model.add(tf.keras.layers.Dropout(0.25))

##set 4
model.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu'))

model.add(tf.keras.layers.MaxPool2D(2,2))  # 4 X 4 X 64

#model.add(tf.keras.layers.Dropout(0.25))

##set 5
model.add(tf.keras.layers.Conv2D(128, (3,3), activation='relu'))

model.add(tf.keras.layers.MaxPool2D(2,2))  # 4 X 4 X 128

#model.add(tf.keras.layers.Dropout(0.25))

# ## Set 6
model.add(tf.keras.layers.Conv2D(256, (3,3), activation='relu'))

#model.add(tf.keras.layers.BatchNormalization())

#model.add(tf.keras.layers.Dropout(0.25))

## Set 7
model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(256, activation='softmax'))


model.add(tf.keras.layers.Dropout(0.5))

#model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(5))

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor= 'val_loss',
    patience= PATIENCE,
    mode = 'auto',
    baseline= None,
    verbose = 1,
    restore_best_weights=True,
    start_from_epoch= 0
)

lr_decay = tf.keras.callbacks.ReduceLROnPlateau(
    monitor= 'val_loss',
    factor= FACTOR_LR,
    patience= PATIENCE,
    mode = 'auto',
    verbose = 1,
)

# %%
modelFile = os.path.join(modelDir, subDir, altname)

model_callback = tf.keras.callbacks.ModelCheckpoint(
    modelFile,
    monitor= 'val_loss',
    mode = 'auto',
    verbose = 1,
    save_best_only=True,
    save_weights_only=True
)

# %%
optim = tf.keras.optimizers.Adam(learning_rate = ALPHA)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model.compile(optimizer = optim, loss = loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(train_ds, validation_data=test_ds, epochs=EPOCHS, verbose = 1,batch_size=BATCH_SIZE,
                    callbacks=[early_stopping, lr_decay])
# Out:
# Epoch 1/150
# 92/92 [==============================] - 30s 252ms/step - loss: 1.5802 - accuracy: 0.3035 - val_loss: 1.5550 - val_accuracy: 0.3787 - lr: 5.0000e-04
# Epoch 2/150
# 92/92 [==============================] - 17s 179ms/step - loss: 1.5483 - accuracy: 0.3198 - val_loss: 1.5354 - val_accuracy: 0.3733 - lr: 5.0000e-04
# Epoch 3/150
# 92/92 [==============================] - 21s 229ms/step - loss: 1.5233 - accuracy: 0.3266 - val_loss: 1.5159 - val_accuracy: 0.3869 - lr: 5.0000e-04
# Epoch 4/150
# 92/92 [==============================] - 21s 223ms/step - loss: 1.5156 - accuracy: 0.3229 - val_loss: 1.5083 - val_accuracy: 0.3801 - lr: 5.0000e-04
# Epoch 5/150
# 92/92 [==============================] - 22s 237ms/step - loss: 1.5049 - accuracy: 0.3256 - val_loss: 1.4997 - val_accuracy: 0.3910 - lr: 5.0000e-04
# Epoch 6/150
# 92/92 [==============================] - 20s 216ms/step - loss: 1.4931 - accuracy: 0.3239 - val_loss: 1.4852 - val_accuracy: 0.3937 - lr: 5.0000e-04
# Epoch 7/150
# 92/92 [==============================] - 22s 236ms/step - loss: 1.4805 - accuracy: 0.3345 - val_loss: 1.4804 - val_accuracy: 0.3815 - lr: 5.0000e-04
# Epoch 8/150
# 92/92 [==============================] - 20s 222ms/step - loss: 1.4920 - accuracy: 0.3202 - val_loss: 1.4673 - val_accuracy: 0.3978 - lr: 5.0000e-04
# Epoch 9/150
# 92/92 [==============================] - 22s 235ms/step - loss: 1.4735 - accuracy: 0.3249 - val_loss: 1.4664 - val_accuracy: 0.3896 - lr: 5.0000e-04
# Epoch 10/150
# 92/92 [==============================] - 21s 229ms/step - loss: 1.4685 - accuracy: 0.3212 - val_loss: 1.4458 - val_accuracy: 0.3978 - lr: 5.0000e-04
# Epoch 11/150
# 92/92 [==============================] - 21s 224ms/step - loss: 1.4603 - accuracy: 0.3331 - val_loss: 1.4632 - val_accuracy: 0.3924 - lr: 5.0000e-04
# Epoch 12/150
# 92/92 [==============================] - 21s 223ms/step - loss: 1.4539 - accuracy: 0.3287 - val_loss: 1.4472 - val_accuracy: 0.3896 - lr: 5.0000e-04
# Epoch 13/150
# 92/92 [==============================] - 20s 221ms/step - loss: 1.4489 - accuracy: 0.3280 - val_loss: 1.4372 - val_accuracy: 0.3869 - lr: 5.0000e-04
# Epoch 14/150
# 92/92 [==============================] - 18s 191ms/step - loss: 1.4426 - accuracy: 0.3348 - val_loss: 1.4187 - val_accuracy: 0.3951 - lr: 5.0000e-04
# Epoch 15/150
# 92/92 [==============================] - 20s 218ms/step - loss: 1.4268 - accuracy: 0.3369 - val_loss: 1.4110 - val_accuracy: 0.3951 - lr: 5.0000e-04
# Epoch 16/150
# 92/92 [==============================] - 20s 222ms/step - loss: 1.4183 - accuracy: 0.3828 - val_loss: 1.4147 - val_accuracy: 0.4060 - lr: 5.0000e-04
# Epoch 17/150
# 92/92 [==============================] - 20s 220ms/step - loss: 1.4068 - accuracy: 0.3702 - val_loss: 1.3971 - val_accuracy: 0.4673 - lr: 5.0000e-04
# Epoch 18/150
# 92/92 [==============================] - 20s 223ms/step - loss: 1.3977 - accuracy: 0.4370 - val_loss: 1.3743 - val_accuracy: 0.4659 - lr: 5.0000e-04
# Epoch 19/150
# 92/92 [==============================] - 20s 221ms/step - loss: 1.3858 - accuracy: 0.4298 - val_loss: 1.3764 - val_accuracy: 0.4605 - lr: 5.0000e-04
# Epoch 20/150
# 92/92 [==============================] - 21s 225ms/step - loss: 1.3988 - accuracy: 0.4142 - val_loss: 1.3713 - val_accuracy: 0.4210 - lr: 5.0000e-04
# Epoch 21/150
# 92/92 [==============================] - 22s 238ms/step - loss: 1.3726 - accuracy: 0.4339 - val_loss: 1.3555 - val_accuracy: 0.4632 - lr: 5.0000e-04
# Epoch 22/150
# 92/92 [==============================] - 22s 235ms/step - loss: 1.3728 - accuracy: 0.4339 - val_loss: 1.3393 - val_accuracy: 0.4632 - lr: 5.0000e-04
# Epoch 23/150
# 92/92 [==============================] - 22s 242ms/step - loss: 1.3610 - accuracy: 0.4578 - val_loss: 1.3284 - val_accuracy: 0.4741 - lr: 5.0000e-04
# Epoch 24/150
# 92/92 [==============================] - 26s 281ms/step - loss: 1.3565 - accuracy: 0.4748 - val_loss: 1.3394 - val_accuracy: 0.4918 - lr: 5.0000e-04
# Epoch 25/150
# 92/92 [==============================] - 34s 369ms/step - loss: 1.3438 - accuracy: 0.4864 - val_loss: 1.3352 - val_accuracy: 0.4918 - lr: 5.0000e-04
# Epoch 26/150
# 92/92 [==============================] - 34s 364ms/step - loss: 1.3479 - accuracy: 0.4806 - val_loss: 1.3103 - val_accuracy: 0.5232 - lr: 5.0000e-04
# Epoch 27/150
# 92/92 [==============================] - 27s 289ms/step - loss: 1.3385 - accuracy: 0.4710 - val_loss: 1.3053 - val_accuracy: 0.5272 - lr: 5.0000e-04
# Epoch 28/150
# 92/92 [==============================] - 10s 114ms/step - loss: 1.3161 - accuracy: 0.4905 - val_loss: 1.3030 - val_accuracy: 0.5545 - lr: 5.0000e-04
# Epoch 29/150
# 92/92 [==============================] - 13s 137ms/step - loss: 1.3346 - accuracy: 0.4826 - val_loss: 1.3020 - val_accuracy: 0.5341 - lr: 5.0000e-04
# Epoch 30/150
# 92/92 [==============================] - 23s 249ms/step - loss: 1.3134 - accuracy: 0.4874 - val_loss: 1.2930 - val_accuracy: 0.5313 - lr: 5.0000e-04
# Epoch 31/150
# 92/92 [==============================] - 21s 233ms/step - loss: 1.3171 - accuracy: 0.4871 - val_loss: 1.2856 - val_accuracy: 0.5490 - lr: 5.0000e-04
# Epoch 32/150
# 92/92 [==============================] - 21s 229ms/step - loss: 1.3012 - accuracy: 0.4888 - val_loss: 1.2692 - val_accuracy: 0.5599 - lr: 5.0000e-04
# Epoch 33/150
# 92/92 [==============================] - 11s 114ms/step - loss: 1.2976 - accuracy: 0.4942 - val_loss: 1.2635 - val_accuracy: 0.5572 - lr: 5.0000e-04
# Epoch 34/150
# 92/92 [==============================] - 10s 110ms/step - loss: 1.2754 - accuracy: 0.4963 - val_loss: 1.2714 - val_accuracy: 0.5477 - lr: 5.0000e-04
# Epoch 35/150
# 92/92 [==============================] - 10s 114ms/step - loss: 1.3002 - accuracy: 0.4837 - val_loss: 1.2635 - val_accuracy: 0.5695 - lr: 5.0000e-04
# Epoch 36/150
# 92/92 [==============================] - 11s 114ms/step - loss: 1.2827 - accuracy: 0.5034 - val_loss: 1.2779 - val_accuracy: 0.5313 - lr: 5.0000e-04
# Epoch 37/150
# 92/92 [==============================] - 11s 117ms/step - loss: 1.2873 - accuracy: 0.4908 - val_loss: 1.3616 - val_accuracy: 0.4332 - lr: 5.0000e-04
# Epoch 38/150
# 92/92 [==============================] - 11s 115ms/step - loss: 1.3010 - accuracy: 0.4837 - val_loss: 1.2827 - val_accuracy: 0.5654 - lr: 5.0000e-04
# Epoch 39/150
# 92/92 [==============================] - 11s 115ms/step - loss: 1.2827 - accuracy: 0.4922 - val_loss: 1.2459 - val_accuracy: 0.5777 - lr: 5.0000e-04
# Epoch 40/150
# 92/92 [==============================] - 11s 117ms/step - loss: 1.2779 - accuracy: 0.4959 - val_loss: 1.2561 - val_accuracy: 0.5531 - lr: 5.0000e-04
# Epoch 41/150
# 92/92 [==============================] - 11s 117ms/step - loss: 1.2793 - accuracy: 0.4932 - val_loss: 1.2436 - val_accuracy: 0.5763 - lr: 5.0000e-04
# Epoch 42/150
# 92/92 [==============================] - 11s 114ms/step - loss: 1.2510 - accuracy: 0.5123 - val_loss: 1.2343 - val_accuracy: 0.5804 - lr: 5.0000e-04
# Epoch 43/150
# 92/92 [==============================] - 11s 116ms/step - loss: 1.2640 - accuracy: 0.4983 - val_loss: 1.2376 - val_accuracy: 0.5967 - lr: 5.0000e-04
# Epoch 44/150
# 92/92 [==============================] - 11s 119ms/step - loss: 1.2470 - accuracy: 0.5065 - val_loss: 1.2206 - val_accuracy: 0.5872 - lr: 5.0000e-04
# Epoch 45/150
# 92/92 [==============================] - 11s 117ms/step - loss: 1.2323 - accuracy: 0.5225 - val_loss: 1.1953 - val_accuracy: 0.6049 - lr: 5.0000e-04
# Epoch 46/150
# 92/92 [==============================] - 11s 116ms/step - loss: 1.2243 - accuracy: 0.5211 - val_loss: 1.1983 - val_accuracy: 0.6063 - lr: 5.0000e-04
# Epoch 47/150
# 92/92 [==============================] - 11s 118ms/step - loss: 1.2303 - accuracy: 0.5031 - val_loss: 1.1831 - val_accuracy: 0.6144 - lr: 5.0000e-04
# Epoch 48/150
# 92/92 [==============================] - 10s 114ms/step - loss: 1.2398 - accuracy: 0.5167 - val_loss: 1.1881 - val_accuracy: 0.5954 - lr: 5.0000e-04
# Epoch 49/150
# 92/92 [==============================] - 11s 117ms/step - loss: 1.2121 - accuracy: 0.5324 - val_loss: 1.1523 - val_accuracy: 0.6158 - lr: 5.0000e-04
# Epoch 50/150
# 92/92 [==============================] - 11s 115ms/step - loss: 1.2046 - accuracy: 0.5293 - val_loss: 1.1463 - val_accuracy: 0.6226 - lr: 5.0000e-04
# Epoch 51/150
# 92/92 [==============================] - 11s 118ms/step - loss: 1.1852 - accuracy: 0.5446 - val_loss: 1.1386 - val_accuracy: 0.6144 - lr: 5.0000e-04
# Epoch 52/150
# 92/92 [==============================] - 10s 113ms/step - loss: 1.1904 - accuracy: 0.5303 - val_loss: 1.1708 - val_accuracy: 0.5926 - lr: 5.0000e-04
# Epoch 53/150
# 92/92 [==============================] - 10s 114ms/step - loss: 1.1869 - accuracy: 0.5395 - val_loss: 1.1124 - val_accuracy: 0.6294 - lr: 5.0000e-04
# Epoch 54/150
# 92/92 [==============================] - 10s 112ms/step - loss: 1.1664 - accuracy: 0.5535 - val_loss: 1.0945 - val_accuracy: 0.6376 - lr: 5.0000e-04
# Epoch 55/150
# 92/92 [==============================] - 11s 115ms/step - loss: 1.1650 - accuracy: 0.5490 - val_loss: 1.1131 - val_accuracy: 0.6199 - lr: 5.0000e-04
# Epoch 56/150
# 92/92 [==============================] - 11s 114ms/step - loss: 1.1570 - accuracy: 0.5671 - val_loss: 1.1225 - val_accuracy: 0.6144 - lr: 5.0000e-04
# Epoch 57/150
# 92/92 [==============================] - 11s 115ms/step - loss: 1.1453 - accuracy: 0.5702 - val_loss: 1.0980 - val_accuracy: 0.6308 - lr: 5.0000e-04
# Epoch 58/150
# 92/92 [==============================] - 11s 118ms/step - loss: 1.1473 - accuracy: 0.5736 - val_loss: 1.1159 - val_accuracy: 0.6063 - lr: 5.0000e-04
# Epoch 59/150
# 92/92 [==============================] - 11s 121ms/step - loss: 1.1402 - accuracy: 0.5616 - val_loss: 1.0741 - val_accuracy: 0.6376 - lr: 5.0000e-04
# Epoch 60/150
# 92/92 [==============================] - 11s 121ms/step - loss: 1.1266 - accuracy: 0.5698 - val_loss: 1.0745 - val_accuracy: 0.6253 - lr: 5.0000e-04
# Epoch 61/150
# 92/92 [==============================] - 11s 120ms/step - loss: 1.1216 - accuracy: 0.5780 - val_loss: 1.0765 - val_accuracy: 0.6144 - lr: 5.0000e-04
# Epoch 62/150
# 92/92 [==============================] - 11s 119ms/step - loss: 1.1194 - accuracy: 0.5753 - val_loss: 1.0819 - val_accuracy: 0.6308 - lr: 5.0000e-04
# Epoch 63/150
# 92/92 [==============================] - 11s 119ms/step - loss: 1.1028 - accuracy: 0.5879 - val_loss: 1.0720 - val_accuracy: 0.6294 - lr: 5.0000e-04
# Epoch 64/150
# 92/92 [==============================] - 11s 119ms/step - loss: 1.0865 - accuracy: 0.5906 - val_loss: 1.0466 - val_accuracy: 0.6308 - lr: 5.0000e-04
# Epoch 65/150
# 92/92 [==============================] - 11s 119ms/step - loss: 1.0853 - accuracy: 0.5848 - val_loss: 1.0400 - val_accuracy: 0.6322 - lr: 5.0000e-04
# Epoch 66/150
# 92/92 [==============================] - 11s 118ms/step - loss: 1.0764 - accuracy: 0.5909 - val_loss: 1.0260 - val_accuracy: 0.6458 - lr: 5.0000e-04
# Epoch 67/150
# 92/92 [==============================] - 11s 119ms/step - loss: 1.0850 - accuracy: 0.5831 - val_loss: 1.0358 - val_accuracy: 0.6417 - lr: 5.0000e-04
# Epoch 68/150
# 92/92 [==============================] - 11s 115ms/step - loss: 1.0597 - accuracy: 0.6005 - val_loss: 1.0041 - val_accuracy: 0.6526 - lr: 5.0000e-04
# Epoch 69/150
# 92/92 [==============================] - 11s 116ms/step - loss: 1.0587 - accuracy: 0.5930 - val_loss: 1.0071 - val_accuracy: 0.6649 - lr: 5.0000e-04
# Epoch 70/150
# 65/92 [====================>.........] - ETA: 3s - loss: 1.0430 - accuracy: 0.6062

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_7 (Rescaling)     (None, 190, 190, 3)       0
#
#  sequential_14 (Sequential)  (None, 190, 190, 3)       0
#
#  conv2d_42 (Conv2D)          (None, 188, 188, 8)       224
#
#  max_pooling2d_35 (MaxPooli  (None, 94, 94, 8)         0
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 92, 92, 16)        1168
#
#  dropout_7 (Dropout)         (None, 92, 92, 16)        0
#
#  max_pooling2d_36 (MaxPooli  (None, 46, 46, 16)        0
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 44, 44, 32)        4640
#
#  max_pooling2d_37 (MaxPooli  (None, 22, 22, 32)        0
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 20, 20, 64)        18496
#
#  max_pooling2d_38 (MaxPooli  (None, 10, 10, 64)        0
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_39 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  conv2d_47 (Conv2D)          (None, 2, 2, 256)         295168
#
#  flatten_7 (Flatten)         (None, 1024)              0
#
#  dense_14 (Dense)            (None, 256)               262400
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 657237 (2.51 MB)
# Trainable params: 657237 (2.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy      lr
# 0  1.595865  0.261921  1.600415      0.239782  0.0005
# 1  1.573389  0.274864  1.590739      0.284741  0.0005
# 2  1.557761  0.282016  1.541108      0.356948  0.0005
# 3  1.546280  0.295640  1.533092      0.356948  0.0005
# 4  1.528298  0.324591  1.520448      0.373297  0.0005

# %%
fig, axes = plt.subplots(1,2 , figsize = (15,6))

l_range = 50

ax = axes[0]
y1 = loss_df.columns[0]
y2 = loss_df.columns[2]

loss_df.plot( y = [y1, y2], ax = ax)

# little beautification
txtstr = "Errors: \n  Start : {:7.4f}\n   End : {:7.4f}".format(loss_df.iloc[0][y1],
                                                                loss_df.iloc[-1][y2]) #text to plot

# properties  matplotlib.patch.Patch 
props = dict(boxstyle='round', facecolor='aqua', alpha=0.5)

# place a text box in upper left in axes coords

ax.text(0.6, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.set_xlabel("Epochs")
ax.set_ylabel("Error")
ax.set_title('Overall')
ax.grid();

ax = axes[1]
y1 = loss_df.columns[1]
y2 = loss_df.columns[3]
loss_df[-l_range:].plot( y = [y1, y2], ax = ax)

# little beautification
txtstr = "Errors: \n  Start : {:7.4f}\n   End : {:7.4f}".format(loss_df.iloc[0][y1],
                                                                loss_df.iloc[-1][y2]) #text to plot

# place a text box in upper left in axes coords

ax.text(0.6, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.set_xlabel("Epochs")
ax.set_ylabel("Metrics")
ax.set_title(y1.capitalize())
ax.grid();
plt.tight_layout()

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#        loss  accuracy  val_loss  val_accuracy      lr
# 32  1.28143  0.504428  1.225793      0.598093  0.0005

# %%
savePath = os.path.join(modelDir, subDir, 'CNN')
tf.keras.models.save_model(model, savePath)
# Out:
# INFO:tensorflow:Assets written to: .../models/flower_photos/CNN/assets
# INFO:tensorflow:Assets written to: .../models/flower_photos/CNN/assets
