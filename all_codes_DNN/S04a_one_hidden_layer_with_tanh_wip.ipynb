# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 04a
# ### Neural Network with :
# - One hidden layer
# - ${Tanh}$ activation function
# - Compare with Tensorflow implementation
#
#
# <img src='../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections.abc import Callable
from typing import Literal

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %matplotlib inline

# %%
###----------------
### Some parameters
###----------------

inpDir = '../input'
outDir = '../output'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 20001 # number of epochs
ALPHA = 0.1 # learning rate
NUM_SAMPLES = 1280 # How many samples we want to generate 
NOISE = 0.2 # Noise to be introduced in the data
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %% [markdown]
# ### Helper Functions

# %%
###-------------------------
### Function to plot history
###-------------------------

#### Note this function is specifically designed to plot Tensorflow training output

def fn_plot_hist(hist_df : pd.DataFrame):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
    
    # create figure and axis array
    fig, axes = plt.subplots(1,2 , figsize = (15,6)) 

    
    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)

    
    # take first axis
    ax = axes[0]
    
    
    # Plot Column 0 and 2 (Loss and validation loss)
    hist_df.plot(y = [hist_df.columns[0],hist_df.columns[2]], 
                 ax = ax,
                 colormap=CMAP) 

    # get minimum values for plotting
    lossmin = hist_df[hist_df.columns[0]].min()
    
    testmin = hist_df[hist_df.columns[2]].min()

    
    # little beautification
    txtstr = "Min {}: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(hist_df.columns[0],
                                                                          lossmin,
                                                                          testmin) #text to plot

    # place a text box in upper middle in axes coords.
    ax.text(0.4, 0.95, txtstr,
            transform=ax.transAxes,
            fontsize=14,
            verticalalignment='top',
            bbox=props)

    # x axis label
    ax.set_xlabel("Epochs")

    # y axis label
    ax.set_ylabel(hist_df.columns[0].capitalize())
    
    # Show grids on the axis
    ax.grid()
    
    
    # take second axis object
    ax = axes[1]

    # plot column 1 and 3 (accuracy and validation accuracy)
    hist_df.plot( y = [hist_df.columns[1], hist_df.columns[3]],
                 ax = ax, 
                 colormap=CMAP)

    
    # little beautification
    accmin = hist_df[hist_df.columns[1]].max()
    
    testmin = hist_df[hist_df.columns[3]].max()
    
    txtstr = "Max {}: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(hist_df.columns[1],
                                                                          accmin,
                                                                          testmin) #text to plot
    
    # place a text box in upper left in axes coords.
    ax.text(0.4, 0.5, txtstr, 
            transform=ax.transAxes,
            fontsize=14,
            verticalalignment='top',
            bbox=props)

    ax.set_xlabel("Epochs")
    ax.set_ylabel(hist_df.columns[1].capitalize())
    ax.grid();
    plt.tight_layout()

# %%
###-----------------------------------
### Function to plot Decision boundary
###-----------------------------------

def fn_plot_decision_boundary(pred_func: Callable[[], np.float64], X_tr: np.ndarray, y_tr: np.ndarray, X_ts :  np.ndarray, y_ts:  np.ndarray,):
    '''
        Attrib:
           pred_func : function based on predict method of the classifier
           X_tr : train feature matrix
           y_tr : train labels
           X_ts : test feature matrix
           y_ts : test labels
       Return:
           None
    '''
    
    # Set min and max values and give it some padding
    xMin, xMax = X_tr[:, 0].min() - .05, X_tr[:, 0].max() + .05
    yMin, yMax = X_tr[:, 1].min() - .05, X_tr[:, 1].max() + .05
    
    # grid size for mesh grid
    h = 0.01
    
    # Generate a grid of points with distance 'h' between them
    xx, yy = np.meshgrid(np.arange(xMin, xMax, h), np.arange(yMin, yMax, h))
    
    # Predict the function value for the whole grid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    
    # Make its shape same as that of xx 
    Z = Z.reshape(xx.shape)

    fig = plt.figure()
    ax = fig.add_axes(111)
    
    # Now we have Z value corresponding to each of the combination of xx and yy
    # Plot the contour and training examples
    ax.contourf(xx, yy, Z, cmap=CMAP) #, alpha = 0.8
    
    # Plotting scatter for train data
    ax.scatter(X_tr[:, 0], X_tr[:, 1], c=y_tr,
                                  s=30, edgecolor='k', cmap=plt.cm.coolwarm)
    
    
    # Plotting scatter for test data
    ax.scatter(X_ts[:, 0], X_ts[:, 1], c=y_ts,
                                  s=150, marker = '*',edgecolor='k', cmap=plt.cm.inferno )

# %% [markdown]
# ## Generate Data Set
# <p style="font-family: Arial; font-size:1.2em;color:black;">
# Use Sklearn's dataset generator <a href="http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html">make_moon</a>.
# </p>

# %%
X, y = datasets.make_moons(n_samples=NUM_SAMPLES, shuffle=True, noise=NOISE, random_state=RANDOM_STATE)

# %%
# Lets Plot the data
plt.scatter(X[:,0], X[:,1], s=40, c=y, marker='*', cmap=CMAP)

plt.grid()

# %%
#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE,
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1024, 2) (1024,) (256, 2) (256,)

# %%
# if you really want to save on space, convert to float32

X_train = X_train.astype(np.float32)

X_test = X_test.astype(np.float32)

y_train = y_train.astype(np.float32)

y_test = y_test.astype(np.float32)

# %% [markdown]
# ## Single neuron
# <img src="../../images/dnn_nb_s03_fig1.png" width='400' align = 'left'>

# %% [markdown]
# ## Single Perceptron
# <img src="../../images/dnn_nb_s03_fig2.png" width='400' align = 'left'>

# %% [markdown]
# ### For single row of perceptrons:
# <img src="../../images/dnn_nb_s04_fig3.png" width='800' align = 'left' alt = 'Two in a row'>

# %% [markdown]
# ### For single perceptron:
#
# $
# \begin{aligned}
# a &=  \sigma(z)\\
# a &=  \sigma(x_1.w_1 + x_2.w_2 + b)\\
# a &= \sigma\ ( [ x_1, x_2 ] \circ
# \begin{bmatrix} w_1 \\ w_2 \end{bmatrix}  + b )\\
# \end{aligned}
# $

# %% [markdown]
# #### For multiple Rows of X:
#
# $
# \begin{aligned}
# a &= \sigma\ (\begin{bmatrix} x_1^{(1)} & x_2^{(1)}\\
# x_1^{(2)} & x_2^{(2)}\\
# x_1^{(...)} & x_2^{(...)}\\
# x_1^{(m)} & x_2^{(m)} \end{bmatrix} \circ
# \begin{bmatrix} w_1 \\ w_2 \end{bmatrix}  + b )\\
# \end{aligned}
# $

# %% [markdown]
# In matrix form it can be represented as:
#
# $
# \begin{aligned}
# a &= \sigma\ ( X_{shape = (m,2)} \circ W_{shape = (2,1)}^{[1]} + b_{shape = (1,1)})
# \end{aligned}
# $
#
# **Note:** Please note that Python is going to broadcast b in all $'m'$ rows. Avoid any confusion, always maintain dimensions of $b$.

# %% [markdown]
# ### For single row of perceptrons:
#
# $
# \begin{aligned}
# a^{[1]} &= g ( X_{shape = (m,2)} \circ W_{shape = (2,1)}^{[1]} + b_{shape = (1,1)}^{[1]})\\
# a^{[2]} &= \sigma ( a^{[1]}_{shape = (m,1)} \circ W_{shape = (1,1)}^{[2]} + b_{shape = (1,1)}^{[2]})\\
# Cost &= \text{Loss function} (y \circ log_e (a^{[2]}))
# \end{aligned}
# $
#
# We will be using $\tanh$ function for layer 1 (hidden layer) as it fits in majority of cases and its derivative can simply be represented as 1 -$\tanh^2(z_1)$. Since our output is binary, it makes sense to use $\text{Sigmoid}$ in the last layer.

# %% [markdown]
# ## Neural Network
#
# Let's start with simple network. Our data has **two** features. Hence size of input layer will also be two. The output is binary, we can code it as single column as well as double column output. The hidden layer could be of **any size**. One need to execute a handful of iterations to arrive at right size of hidden layer. For purpose of today's discussions, size of hidden layer is taken as shown below.
# <img src='../../images/dnn_nb_s04_fig1.png' width = '500'/>

# %% [markdown]
# <img src='../../images/dnn_nb_s04_fig2.png' width = '500'/>

# %% [markdown]
# ## What is this hidden layer?
#
# <img src='../../images/dnn_nb_s04_fig5.png' width = '500'/>

# %% [markdown]
# ## Forward Propagation
#
# ### For single Neuron:
# $\text{activations (a)} = \text{activation function} ( X \circ W_1 + b)$

# %% [markdown]
# Hence for hidden layer, we can write as follows:
#
# $
# \begin{aligned}
# z_1^{[1]} & = X . W_1^{[1]} + b_1^{[1]}\\
# a_1^{[1]} & = \tanh(z_1^{[1]}) \\
# \\
# z_2^{[1]} & = X . W_2^{[1]} + b_2^{[1]} \\
# a_2^{[1]} & = \tanh(z_2^{[1]}) \\
# \\
# z_3^{[1]} & = X . W_3^{[1]} + b_3^{[1]} \\
# a_3^{[1]} & = \tanh(z_3^{[1]}) \\
# \\
# z_4^{[1]} & = X . W_4^{[1]} + b_4^{[1]} \\
# a_4^{[1]} & = \tanh(z_4^{[1]}) \\
# \\
# \text{Or}\\
# a^{[1]} &= \tanh(X \circ \begin{bmatrix} W_1^{[1]}, &W_2^{[1]}, &W_3^{[1]}, &W_4^{[1]}\end{bmatrix} + \begin{bmatrix}b_1^{[1]}, &b_2^{[1]}, &b_3^{[1]}, &b_4^{[1]}\end{bmatrix} )\\
# \end{aligned}
# $
#
#
#
# <hr>
#
# If we convert above to matrix version, we can say.
#
# $
# \begin{aligned}
# \text{Replace:}\\
# W^{[1]} & = \begin{bmatrix} W_1^{[1]}, &W_2^{[1]}, &W_3^{[1]}, &W_4^{[1]}\end{bmatrix}\\
# b^{[1]} & = \begin{bmatrix}b_1^{[1]}, &b_2^{[1]}, &b_3^{[1]}, &b_4^{[1]}\end{bmatrix}\\
# \text{Hence:}
# \\z_{shape = (m,4)}^{[1]} & = X_{shape = (m,2)} \circ W_{shape=(2,4)}^{[1]} + b_{shape = (1,4)}^{[1]} \\
# \\
# a_{shape = (m,4)}^{[1]} & = \tanh(z^{[1]}) \\
# \end{aligned}
# $
#
# Similarly for second layer.
#
# $
# \begin{aligned}
# z_{shape = (m, 1)}^{[2]} & = a_{shape = (m,4)}^{[1]} \circ W_{shape=(4,1)}^{[2]} + b_{shape = (1,1)}^{[2]} \\
# \\
# a_{shape = (m, 1)}^{[2]} & = \hat{y} = \mathrm{sigmoid}(z^{[2]})\\
# \end{aligned}
# $
#
# Where:
#
# Sigmoid $\sigma$:
#
# $\sigma(z) = \dfrac{1}{1 + e^{-z}}$
#
# ## Activation Functions
#
# ### Sigmoid Function

# %%
# sigmoid function is applied to each Value independently
def fn_sigmoid(z : np.ndarray)-> np.ndarray:
    '''
    Args:
        z : a matrix of z values of shape (m, n_output)
    returns:
        sigmoid values of z
    
    '''
    
    return 1 / ( 1 + np.exp ( -z ) )

# %%
sm = fn_sigmoid(np.asarray([[-1, 0., 1.], [-np.inf, 0., np.inf]]))
print (sm)
# Out:
# [[0.26894142 0.5        0.73105858]
#  [0.         0.5        1.        ]]

# %% [markdown]
# ### Tanh Activation Function

# %%
def fn_tanh(z: np.ndarray) -> np.ndarray:
    
    '''
        Args:
           z : array, Aggregated values 
       Return:
           Activations for each z
    '''

    return np.tanh(z)

def fn_tanh_prime(a: np.ndarray) -> np.ndarray:
    '''
        Args:
           a : array, Aggregated values 
       Return:
           Derivative, for each a
    '''

    return 1.0 - np.tanh(a)**2

# %%
fn_tanh(np.asarray([[-1, 0., 1.], [-np.inf, 0., np.inf]]))
# Out:
# array([[-0.76159416,  0.        ,  0.76159416],
#        [-1.        ,  0.        ,  1.        ]])

# %% [markdown]
# ### Is our Activation Function working?

# %%
np.tanh(0.5)
# Out:
# 0.46211715726000974

# %%
(1 - np.power(np.tanh(0.5), 2))
# Out:
# 0.7864477329659274

# %%
fn_tanh_prime(0.5)
# Out:
# 0.7864477329659274

# %% [markdown]
# ## Predict Function
#
# For predictions, we will simply be using the forward propagation. No need to iterate or calculate the back propagation for supervised learning.

# %%
# Helper function to predict an output (0 or 1)

def predict(model : dict, X: np.ndarray) -> Literal:
    '''
     Args:
         model
         X: input features
    Returns:
        Predictions against the instances
         
    '''
    W1, b1, W2, b2 = model['W1'],model['b1'],model['W2'],model['b2']
    
    #### Forward Propagation   
    # Layer 1
    z1 = X.dot(W1) + b1 # Aggregation
    a1 = fn_tanh (z1) # Activation

    # Layer 2
    z2 = a1.dot(W2) + b2
    a2 = fn_sigmoid(z2)
    
    return a2>=0.5 # Is it greater than 0.5?

# %% [markdown]
# ## Loss Function
#
# We need to minimize the error by adjusting ($W_s, b_s$). We call the function that measures our error the <b>loss function</b>. A common choice with the sigmoid output is the cross-entropy loss. The loss for predictions $\hat{y}$ with respect to the true labels $y$ is given by:
#
# $
# \begin{aligned}
# L(\hat{y_i}, y_i) =  -\begin{bmatrix}y_i.log(\hat{y_i}) + (1 - y_i) . log(1-\hat{y_i})\end{bmatrix}\\
# \end{aligned}
# $
#
# For all samples:
#
# $
# \begin{aligned}
# J(\hat{y}, y) =  -\frac{1}{m}\sum_{i=1}^{m}\begin{bmatrix}y_i.log(\hat{y}_i) + (1-y_i) . log(1-\hat{y}_i)\end{bmatrix}\\
# \end{aligned}
# $
#
# ### In case of Binary Classification:
#
# $
# \begin{aligned}
# L(\hat{y_i}, y_i) =  -y_i.log(\hat{y_i})
# \end{aligned}
# $
#
# For all samples:
#
# $
# \begin{aligned}
# J(\hat{y}, y) =  -\frac{1}{m}\sum_{i=1}^{m}y_i.log(\hat{y}_i)
# \end{aligned}
# $
#
#
# We can use gradient descent to find its minimum. For purpose of this Session, let's use it in its simplest form - <b>batch gradient descent with fixed learning rate</b>.

# %%
# function to evaluate the total loss on the dataset

def calculate_loss(model : dict, X: np.ndarray, y: np.ndarray) -> np.float64:
    '''
    Args:
        model: dictionay object containing weights and biases
        X: Feature Matrix
        y: Labels array
    Returns:
        Average loss
    '''
    W1, b1, W2, b2 = model['W1'],model['b1'],model['W2'],model['b2']
    
    #### Forward Propagation   
    # Layer 1
    z1 = X.dot(W1) + b1 # Aggregation
    a1 = fn_tanh (z1) # Activation

    # Layer 2
    z2 = a1.dot(W2) + b2
    a2 = fn_sigmoid(z2)
    
    data_loss = -(y* np.log(a2)).sum()

    return 1./num_examples * data_loss

# %% [markdown]
# ## For a single row of data x
#
# <img src='../../images/dnn_nb_s04_fig4.png' style='width: 800px;'/>

# %% [markdown]
# As an input, gradient descent needs the gradients (vector of derivatives) of the loss function with respect to our parameters:
#
# $\frac{\partial{L}}{\partial{W_1}}(= \partial{W^{[1]}})$, $\frac{\partial{L}}{\partial{b_1}}(= \partial{b^{[1]}})$, $\frac{\partial{L}}{\partial{W_2}}(= \partial{W^{[2]}})$, $\frac{\partial{L}}{\partial{b_2}}(= \partial{b^{[2]}})$.
#
# To calculate these gradients we use the <b>back-propagation algorithm</b>.
#
# **Note:** Loss is a function of $a^{[2]}$ which is a function of $z^{[2]}$ and so on. It can be further represented as follows:<br>
# $
# \begin{aligned}
# Loss &= f_1(a^{[2]})\\
# a^{[2]} &= f_2(z^{[2]})\\
# z^{[2]} &= f_3(a^{[1]})\\
# a^{[1]} &= f_4(z^{[1]})\\
# \text{Therefore:}\\
# \frac{\partial{Loss}}{\partial{z^{[1]}}} &= \frac{\partial{Loss}}{\partial{z^{[2]}}} \circ
# \frac{\partial{z^{[2]}}}{\partial{a^{[1]}}} \circ \frac{\partial{a^{[1]}}}{\partial{z^{[1]}}}
# \end{aligned}
# $

# %% [markdown]
# ## Back-propagation for all Rows
# For all rows, equations will remain same and the values will be divided by <b><i>'m'</i></b>; number of samples.
#
# $
# \begin{aligned}
# \partial{z^{[2]}}  & = a^{[2]} - y  \\
# \partial{W^{[2]}}  & = \frac{1}{m} a^{[1]T}\circ \partial{z^{[2]}} \\
# \partial{b^{[2]}}  & = \frac{1}{m} \mathrm{np.sum}(\partial{z^{[2]}}, axis = 0, keepdims = True) \\
# \\
# \partial{z^{[1]}}  & = \partial{z^{[2]}}\circ  W^{[2]T} * ( 1-a^{[1]}**2)\\
# \partial{W^{[1]}}  & = \frac{1}{m} X^{T}\circ \partial{z^{[1]}} \\
# \partial{b^{[1]}}  & = \frac{1}{m} \mathrm{np.sum}(\partial{z^{[1]}}, axis = 0, keepdims = True) \\
# \\
# \end{aligned}
# $

# %% [markdown]
# ## Notes:
#
#
# We have transposed a few matrices in above calculations such as $a^{[1]}$, $W^{[2]}$ and X. A review of shapes of matrices will reveal that this adjustment is needed to have consistent sizes. e.g.
#
# - Shape of $a^{[1]}$ and $\partial{z}^{[2]}$ are ( m, 4) and ( m, 1 ) respectively. Expected shape of $\partial{W^{[2]}}$ is ( 4, 1 ) which is same as that of $W^{[2]}$.
# - In equation $\partial{z^{[1]}}  = \partial{z^{[2]}}\circ  W^{[2]T} * ( 1-a^{[1]}**2)$ shape of $z^{[2]}$,  $W^{[2]}$ and $a^{[1]}$ are (m,1), (4,1) and (m,4). For element wise multiplication, expected shape of dot product of is $z^{[2]}$ and $W^{[2]}$ is ( m, 4 ).
# - Lastly, shape of $\partial{W^{[1]}}$ is (2,4) and that of X and $\partial{z^{[1]}}$ are ( m, 2 ) and ( m, 4 ).

# %% [markdown]
# ## Model

# %%
# prepare the Model

def build_model(nn_hdim : np.int64, 
                X : np.ndarray, 
                y : np.ndarray, 
                epochs: np.int64 = EPOCHS, 
                alpha: np.float64 = ALPHA) -> dict:
    
    '''
    Args:
        nn_hdim : Number of nodes in the hidden layer
        X : np.ndarray; Training features to train
        y : np.ndarray; Trainig targets (labels)
        epochs : Number of passes through the training data for gradient descent
        alpha : learning rate
        
    Returns:
        Model: Dictionary object containing weights and biases
    '''
    
    # Initialize the parameters to random values. We need to learn these Weights
    
    '''
    ##### 
            Change from Rand to Randn gives different shape of the loss curve
    #####
    '''
    
    W1 = np.random.rand(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    W2 = np.random.rand(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    
    b1 = np.zeros ((1, nn_hdim))
    b2 = np.zeros ((1, nn_output_dim))
    
    curr_loss = 0
    
    loss = []
    epoch = []
    
    for i in range (0, epochs):
        
        #### Forward Propagation
        
        # Layer 1
        z1 = X.dot(W1) + b1 # Aggregation
        a1 = fn_tanh (z1) # Activation
        
        # Layer 2
        z2 = a1.dot(W2) + b2
        a2 = fn_sigmoid(z2)
        
        ### Back Propagation

        # Layer 2
        dz2 = a2 - y
        
        dW2 = (a1.T).dot(dz2)
        assert (W2.shape == dW2.shape), 'Shape of W2 {} and shape of dW2 {}'.format(W2.shape, dW2.shape)
        
        db2 = np.sum(dz2, axis = 0, keepdims=True)
        assert (b2.shape == db2.shape), 'Shape of b2 {} and shape of db2 {}'.format(b2.shape, db2.shape)
        
        da1 = dz2.dot(W2.T)
        assert (a1.shape == da1.shape), 'Shape of a1 {} and shape of da1 {}'.format(a1.shape, da1.shape)

        # Layer 1
        dz1 = da1 * fn_tanh_prime(z1)
        assert (z1.shape == dz1.shape), 'Shape of z1 {} and shape of dz1 {}'.format(z1.shape, dz1.shape)

        dW1 = (X.T).dot(dz1)
        assert (W1.shape == dW1.shape), 'Shape of W1 {} and shape of dW1 {}'.format(W1.shape, dW1.shape)
        db1 = np.sum(dz1, axis = 0, keepdims=True)
        assert (b1.shape == db1.shape), 'Shape of b1 {} and shape of db1 {}'.format(b1.shape, db1.shape)

        ########################
        ### Gradient Updates ###
        ########################
        # gradients are being updated for every epoch
        W1 += -alpha *dW1 / num_examples
        W2 += -alpha *dW2 / num_examples
        b1 += -alpha *db1 / num_examples
        b2 += -alpha *db2 / num_examples
        
        # Store model in a dict object
        model = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
        
        # for every nth epoch calculate loss for future plotting
        if i%100 ==  0:
            curr_loss = calculate_loss (model, X, y)
            loss.append(curr_loss)
            epoch.append(i)
            
        # print loss every nth epoch    
        if i%1000 == 0:
            print ('loss after {} epochs : {}'.format(i,curr_loss))
    
    # update loss_hist
    loss_hist['epoch'] =epoch
    loss_hist['loss'] = loss
    
    
    return model

# %%
num_examples, nn_input_dim = X_train.shape # training set size (rows and cols)
nn_output_dim = 1 # output layer dimensionality

# lists to facilitate plotting 
loss_hist = {}

# %%
num_examples, nn_input_dim
# Out:
# (1024, 2)

# %% [markdown]
# **Note:** - The vector y_train is being converted to 2-dimensional array

# %%
y_train = y_train.reshape(-1,1)
y_train.shape
# Out:
# (1024, 1)

# %%
# Build a model with a 4-dimensional hidden layer
model = build_model(4, X_train, y_train,
                    epochs = EPOCHS, 
                    alpha = ALPHA)
# Out:
# loss after 0 epochs : 0.2975464894196189
# loss after 1000 epochs : 0.148327729184851
# loss after 2000 epochs : 0.10529788144380808
# loss after 3000 epochs : 0.07204699759314803
# loss after 4000 epochs : 0.051189206593804715
# loss after 5000 epochs : 0.0434426250349737
# loss after 6000 epochs : 0.04070659354191448
# loss after 7000 epochs : 0.03959934999765885
# loss after 8000 epochs : 0.03909206747090136
# loss after 9000 epochs : 0.03883557764780686
# loss after 10000 epochs : 0.0386934812357744
# loss after 11000 epochs : 0.03860581493610833
# loss after 12000 epochs : 0.038543401564614
# loss after 13000 epochs : 0.03849049846456406
# loss after 14000 epochs : 0.038437638178642666
# loss after 15000 epochs : 0.038378940802563974
# loss after 16000 epochs : 0.038311779002766166
# loss after 17000 epochs : 0.03823707398518342
# loss after 18000 epochs : 0.03815841707325693
# loss after 19000 epochs : 0.038079885013854384
# loss after 20000 epochs : 0.03800428299830342

# %%
model
# Out:
# {'W1': array([[ 2.79041315,  2.44973647,  3.47216862,  2.91766123],
#         [-1.55566552, -0.64631346,  2.15366289, -1.44832853]]),
#  'b1': array([[-3.48402764,  1.50405901, -2.11977869,  1.25236474]]),
#  'W2': array([[ 6.79080732],
#         [ 3.17545367],
#         [-6.69467415],
#         [ 4.44762638]]),
#  'b2': array([[-0.61155664]])}

# %% [markdown]
# Would contest that we should have used higher epochs as loss is still coming down.
#
# ### Question
# - How many epochs are sufficient?
#
# ## Make predictions

# %%
y_pred = predict(model, X_train)
print('Accuracy score on Train Data :', accuracy_score(y_train, y_pred))
# Out:
# Accuracy score on Train Data : 0.96875

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       522
#          1.0       0.97      0.97      0.97       502
#
#     accuracy                           0.97      1024
#    macro avg       0.97      0.97      0.97      1024
# weighted avg       0.97      0.97      0.97      1024

# %%
y_pred = predict(model, X_test)

print('Accuracy score on Test Data :', accuracy_score(y_test, y_pred))
# Out:
# Accuracy score on Test Data : 0.95703125

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.95       118
#          1.0       0.96      0.96      0.96       138
#
#     accuracy                           0.96       256
#    macro avg       0.96      0.96      0.96       256
# weighted avg       0.96      0.96      0.96       256

# %% [markdown]
# ## Plot loss and decision boundary

# %%
loss_df = pd.DataFrame(loss_hist)

fn_plot_decision_boundary(lambda x: predict(model, x), X_train, y_train, X_test, y_test) # plot decision boundary for this plot

plt.title("Decision Boundary");

# %% [markdown]
# ## How weights mature!
# - See on the video in the output directory.

# %%
fig, axes = plt.subplots(1,2 , figsize = (15,6))

l_range = 50

ax = axes[0]

loss_df.plot(x = 'epoch', y = 'loss', ax = ax)

# little beautification
txtstr = "Errors: \n  Start : {:7.4f}\n   End : {:7.4f}".format(loss_df.iloc[0]['loss'],
                                                                loss_df.iloc[-1]['loss']) #text to plot

# properties  matplotlib.patch.Patch 
props = dict(boxstyle='round', facecolor='aqua', alpha=0.5)

# place a text box in upper left in axes coords

ax.text(0.6, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.set_xlabel("Epochs")
ax.set_ylabel("Error")
ax.set_title('Overall')
ax.grid();

ax = axes[1]

loss_df[-l_range:].plot(x = 'epoch', y = 'loss', ax = ax)

# little beautification
txtstr = "Errors: \n  Start : {:7.4f}\n   End : {:7.4f}".format(loss_df.iloc[-l_range]['loss'],
                                                                loss_df.iloc[-1]['loss']) #text to plot

# place a text box in upper left in axes coords

ax.text(0.6, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.set_xlabel("Epochs")
ax.set_ylabel("Error")
ax.set_title('Last {} records'.format(l_range))
ax.grid();
plt.tight_layout()

# %%
cm  = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[113,   5],
#        [  6, 132]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=[0,1])

fig, ax = plt.subplots(figsize = (4,4))

disp.plot(ax = ax, cmap = 'Blues', colorbar=False)

plt.show();

# %% [markdown]
# ## Verify Results using TensorFlow libraries
# **Note** Tensorflow will be covered in detail in subsequent classes.

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
try:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
        
    logical_gpus = tf.config.list_logical_devices('GPU')
    
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    
except:
    print ('Invalid device or cannot modify virtual devices once initialized.')
    
    pass
# Out:
# 2023-11-21 11:17:31.029390: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 11:17:31.029461: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 11:17:31.046205: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 11:17:31.089721: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 11:17:31.900939: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 1 Physical GPUs, 1 Logical GPUs
# 2023-11-21 11:17:32.934732: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.030153: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.030404: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.032197: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.032414: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.032596: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.099070: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.099329: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.099527: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-21 11:17:33.099680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4059 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
krnl_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)

# Define sequential model with same size and activation functions
tf_model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(4, activation='tanh', kernel_initializer=krnl_init),
    tf.keras.layers.Dense(2, kernel_initializer=krnl_init)
])

# Using cross entropy for loss calculations
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %% [markdown]
# [Optimizer that implements the Adam algorithm.](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)
#
# >tf.keras.optimizers.Adam(
#     learning_rate=0.001,
#     beta_1=0.9,
#     beta_2=0.999,
#     epsilon=1e-07,
#     amsgrad=False,
#     name='Adam',
#     **kwargs
# )

# %%
tf_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=ALPHA),
              loss=loss_fn,
              metrics=['accuracy'])

# %%
# fit and evaluate

history = tf_model.fit(X_train, y_train ,
                       validation_data = [X_test, y_test],
                       epochs = 1000, verbose =2)
# Out:
# Epoch 1/1000
# 2023-11-21 11:17:33.703706: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f24436dfc00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-21 11:17:33.703739: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-11-21 11:17:33.718712: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-21 11:17:33.752982: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2023-11-21 11:17:33.799309: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1700545653.859341    5559 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 32/32 - 1s - loss: 0.4050 - accuracy: 0.7939 - val_loss: 0.3025 - val_accuracy: 0.8711 - 933ms/epoch - 29ms/step
# Epoch 2/1000
# 32/32 - 0s - loss: 0.3109 - accuracy: 0.8662 - val_loss: 0.2954 - val_accuracy: 0.8789 - 51ms/epoch - 2ms/step
# Epoch 3/1000
# 32/32 - 0s - loss: 0.3193 - accuracy: 0.8701 - val_loss: 0.2919 - val_accuracy: 0.8711 - 49ms/epoch - 2ms/step
# Epoch 4/1000
# 32/32 - 0s - loss: 0.3183 - accuracy: 0.8584 - val_loss: 0.3127 - val_accuracy: 0.8750 - 46ms/epoch - 1ms/step
# Epoch 5/1000
# 32/32 - 0s - loss: 0.3142 - accuracy: 0.8701 - val_loss: 0.2886 - val_accuracy: 0.8828 - 47ms/epoch - 1ms/step
# Epoch 6/1000
# 32/32 - 0s - loss: 0.3124 - accuracy: 0.8711 - val_loss: 0.2987 - val_accuracy: 0.8672 - 48ms/epoch - 1ms/step
# Epoch 7/1000
# 32/32 - 0s - loss: 0.3073 - accuracy: 0.8662 - val_loss: 0.2872 - val_accuracy: 0.8711 - 46ms/epoch - 1ms/step
# Epoch 8/1000
# 32/32 - 0s - loss: 0.3115 - accuracy: 0.8633 - val_loss: 0.2982 - val_accuracy: 0.8672 - 46ms/epoch - 1ms/step
# Epoch 9/1000
# 32/32 - 0s - loss: 0.3180 - accuracy: 0.8623 - val_loss: 0.2894 - val_accuracy: 0.8750 - 47ms/epoch - 1ms/step
# Epoch 10/1000
# 32/32 - 0s - loss: 0.3158 - accuracy: 0.8682 - val_loss: 0.3046 - val_accuracy: 0.8789 - 62ms/epoch - 2ms/step
# Epoch 11/1000
# 32/32 - 0s - loss: 0.3205 - accuracy: 0.8594 - val_loss: 0.3193 - val_accuracy: 0.8633 - 46ms/epoch - 1ms/step
# Epoch 12/1000
# 32/32 - 0s - loss: 0.3174 - accuracy: 0.8711 - val_loss: 0.3002 - val_accuracy: 0.8633 - 45ms/epoch - 1ms/step
# Epoch 13/1000
# 32/32 - 0s - loss: 0.3221 - accuracy: 0.8711 - val_loss: 0.3318 - val_accuracy: 0.8828 - 46ms/epoch - 1ms/step
# Epoch 14/1000
# 32/32 - 0s - loss: 0.3143 - accuracy: 0.8701 - val_loss: 0.2927 - val_accuracy: 0.8750 - 48ms/epoch - 2ms/step
# Epoch 15/1000
# 32/32 - 0s - loss: 0.3078 - accuracy: 0.8721 - val_loss: 0.2923 - val_accuracy: 0.8711 - 48ms/epoch - 1ms/step
# Epoch 16/1000
# 32/32 - 0s - loss: 0.3303 - accuracy: 0.8623 - val_loss: 0.2897 - val_accuracy: 0.8711 - 51ms/epoch - 2ms/step
# Epoch 17/1000
# 32/32 - 0s - loss: 0.3079 - accuracy: 0.8750 - val_loss: 0.2935 - val_accuracy: 0.8789 - 47ms/epoch - 1ms/step
# Epoch 18/1000
# 32/32 - 0s - loss: 0.3065 - accuracy: 0.8613 - val_loss: 0.2919 - val_accuracy: 0.8789 - 46ms/epoch - 1ms/step
# Epoch 19/1000
# 32/32 - 0s - loss: 0.3109 - accuracy: 0.8652 - val_loss: 0.3159 - val_accuracy: 0.8828 - 45ms/epoch - 1ms/step
# Epoch 20/1000
# 32/32 - 0s - loss: 0.3148 - accuracy: 0.8672 - val_loss: 0.2885 - val_accuracy: 0.8711 - 46ms/epoch - 1ms/step
# Epoch 21/1000
# 32/32 - 0s - loss: 0.3048 - accuracy: 0.8672 - val_loss: 0.3353 - val_accuracy: 0.8633 - 45ms/epoch - 1ms/step
# Epoch 22/1000
# 32/32 - 0s - loss: 0.3091 - accuracy: 0.8613 - val_loss: 0.2866 - val_accuracy: 0.8711 - 45ms/epoch - 1ms/step
# Epoch 23/1000
# 32/32 - 0s - loss: 0.3000 - accuracy: 0.8750 - val_loss: 0.2845 - val_accuracy: 0.8711 - 47ms/epoch - 1ms/step
# Epoch 24/1000
# 32/32 - 0s - loss: 0.3046 - accuracy: 0.8584 - val_loss: 0.3194 - val_accuracy: 0.8711 - 45ms/epoch - 1ms/step
# Epoch 25/1000
# 32/32 - 0s - loss: 0.2937 - accuracy: 0.8672 - val_loss: 0.2722 - val_accuracy: 0.8789 - 62ms/epoch - 2ms/step
# Epoch 26/1000
# 32/32 - 0s - loss: 0.2150 - accuracy: 0.9170 - val_loss: 0.1615 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 27/1000
# 32/32 - 0s - loss: 0.1405 - accuracy: 0.9482 - val_loss: 0.1579 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 28/1000
# 32/32 - 0s - loss: 0.1143 - accuracy: 0.9570 - val_loss: 0.1385 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 29/1000
# 32/32 - 0s - loss: 0.1155 - accuracy: 0.9590 - val_loss: 0.1182 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 30/1000
# 32/32 - 0s - loss: 0.0978 - accuracy: 0.9600 - val_loss: 0.0978 - val_accuracy: 0.9531 - 48ms/epoch - 2ms/step
# Epoch 31/1000
# 32/32 - 0s - loss: 0.1137 - accuracy: 0.9521 - val_loss: 0.0943 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 32/1000
# 32/32 - 0s - loss: 0.1161 - accuracy: 0.9561 - val_loss: 0.0884 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 33/1000
# 32/32 - 0s - loss: 0.1074 - accuracy: 0.9590 - val_loss: 0.0848 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 34/1000
# 32/32 - 0s - loss: 0.1081 - accuracy: 0.9580 - val_loss: 0.1180 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 35/1000
# 32/32 - 0s - loss: 0.0916 - accuracy: 0.9609 - val_loss: 0.0934 - val_accuracy: 0.9570 - 48ms/epoch - 1ms/step
# Epoch 36/1000
# 32/32 - 0s - loss: 0.0968 - accuracy: 0.9590 - val_loss: 0.1005 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 37/1000
# 32/32 - 0s - loss: 0.0878 - accuracy: 0.9688 - val_loss: 0.1114 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 38/1000
# 32/32 - 0s - loss: 0.0918 - accuracy: 0.9619 - val_loss: 0.0830 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 39/1000
# 32/32 - 0s - loss: 0.0966 - accuracy: 0.9570 - val_loss: 0.1046 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 40/1000
# 32/32 - 0s - loss: 0.0905 - accuracy: 0.9619 - val_loss: 0.0952 - val_accuracy: 0.9648 - 62ms/epoch - 2ms/step
# Epoch 41/1000
# 32/32 - 0s - loss: 0.1013 - accuracy: 0.9600 - val_loss: 0.0892 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 42/1000
# 32/32 - 0s - loss: 0.0979 - accuracy: 0.9648 - val_loss: 0.0898 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 43/1000
# 32/32 - 0s - loss: 0.1048 - accuracy: 0.9570 - val_loss: 0.1437 - val_accuracy: 0.9414 - 45ms/epoch - 1ms/step
# Epoch 44/1000
# 32/32 - 0s - loss: 0.1275 - accuracy: 0.9492 - val_loss: 0.0969 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 45/1000
# 32/32 - 0s - loss: 0.0967 - accuracy: 0.9639 - val_loss: 0.1048 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 46/1000
# 32/32 - 0s - loss: 0.0976 - accuracy: 0.9600 - val_loss: 0.0977 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 47/1000
# 32/32 - 0s - loss: 0.0999 - accuracy: 0.9551 - val_loss: 0.1124 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 48/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9639 - val_loss: 0.1063 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 49/1000
# 32/32 - 0s - loss: 0.0877 - accuracy: 0.9629 - val_loss: 0.0957 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 50/1000
# 32/32 - 0s - loss: 0.0871 - accuracy: 0.9668 - val_loss: 0.1140 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 51/1000
# 32/32 - 0s - loss: 0.0895 - accuracy: 0.9619 - val_loss: 0.1008 - val_accuracy: 0.9570 - 45ms/epoch - 1ms/step
# Epoch 52/1000
# 32/32 - 0s - loss: 0.0972 - accuracy: 0.9629 - val_loss: 0.0935 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 53/1000
# 32/32 - 0s - loss: 0.0983 - accuracy: 0.9619 - val_loss: 0.1064 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 54/1000
# 32/32 - 0s - loss: 0.0987 - accuracy: 0.9580 - val_loss: 0.1298 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 55/1000
# 32/32 - 0s - loss: 0.0992 - accuracy: 0.9639 - val_loss: 0.0901 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 56/1000
# 32/32 - 0s - loss: 0.0941 - accuracy: 0.9639 - val_loss: 0.1014 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 57/1000
# 32/32 - 0s - loss: 0.1205 - accuracy: 0.9521 - val_loss: 0.1070 - val_accuracy: 0.9648 - 49ms/epoch - 2ms/step
# Epoch 58/1000
# 32/32 - 0s - loss: 0.1034 - accuracy: 0.9590 - val_loss: 0.0972 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 59/1000
# 32/32 - 0s - loss: 0.0973 - accuracy: 0.9648 - val_loss: 0.1045 - val_accuracy: 0.9648 - 50ms/epoch - 2ms/step
# Epoch 60/1000
# 32/32 - 0s - loss: 0.0917 - accuracy: 0.9639 - val_loss: 0.1033 - val_accuracy: 0.9648 - 49ms/epoch - 2ms/step
# Epoch 61/1000
# 32/32 - 0s - loss: 0.0881 - accuracy: 0.9668 - val_loss: 0.0852 - val_accuracy: 0.9648 - 48ms/epoch - 2ms/step
# Epoch 62/1000
# 32/32 - 0s - loss: 0.0969 - accuracy: 0.9609 - val_loss: 0.1031 - val_accuracy: 0.9609 - 50ms/epoch - 2ms/step
# Epoch 63/1000
# 32/32 - 0s - loss: 0.0920 - accuracy: 0.9629 - val_loss: 0.1091 - val_accuracy: 0.9531 - 50ms/epoch - 2ms/step
# Epoch 64/1000
# 32/32 - 0s - loss: 0.0957 - accuracy: 0.9648 - val_loss: 0.0900 - val_accuracy: 0.9688 - 48ms/epoch - 2ms/step
# Epoch 65/1000
# 32/32 - 0s - loss: 0.0908 - accuracy: 0.9619 - val_loss: 0.0952 - val_accuracy: 0.9648 - 51ms/epoch - 2ms/step
# Epoch 66/1000
# 32/32 - 0s - loss: 0.0884 - accuracy: 0.9639 - val_loss: 0.1135 - val_accuracy: 0.9609 - 62ms/epoch - 2ms/step
# Epoch 67/1000
# 32/32 - 0s - loss: 0.0960 - accuracy: 0.9619 - val_loss: 0.0884 - val_accuracy: 0.9648 - 64ms/epoch - 2ms/step
# Epoch 68/1000
# 32/32 - 0s - loss: 0.0912 - accuracy: 0.9697 - val_loss: 0.1146 - val_accuracy: 0.9531 - 50ms/epoch - 2ms/step
# Epoch 69/1000
# 32/32 - 0s - loss: 0.0901 - accuracy: 0.9668 - val_loss: 0.1053 - val_accuracy: 0.9570 - 49ms/epoch - 2ms/step
# Epoch 70/1000
# 32/32 - 0s - loss: 0.0914 - accuracy: 0.9639 - val_loss: 0.0920 - val_accuracy: 0.9531 - 48ms/epoch - 1ms/step
# Epoch 71/1000
# 32/32 - 0s - loss: 0.0930 - accuracy: 0.9639 - val_loss: 0.1035 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 72/1000
# 32/32 - 0s - loss: 0.0936 - accuracy: 0.9639 - val_loss: 0.1043 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 73/1000
# 32/32 - 0s - loss: 0.0853 - accuracy: 0.9629 - val_loss: 0.1099 - val_accuracy: 0.9688 - 48ms/epoch - 1ms/step
# Epoch 74/1000
# 32/32 - 0s - loss: 0.0918 - accuracy: 0.9609 - val_loss: 0.1306 - val_accuracy: 0.9453 - 50ms/epoch - 2ms/step
# Epoch 75/1000
# 32/32 - 0s - loss: 0.0933 - accuracy: 0.9609 - val_loss: 0.1129 - val_accuracy: 0.9570 - 55ms/epoch - 2ms/step
# Epoch 76/1000
# 32/32 - 0s - loss: 0.0947 - accuracy: 0.9629 - val_loss: 0.1006 - val_accuracy: 0.9648 - 59ms/epoch - 2ms/step
# Epoch 77/1000
# 32/32 - 0s - loss: 0.0947 - accuracy: 0.9580 - val_loss: 0.1164 - val_accuracy: 0.9453 - 58ms/epoch - 2ms/step
# Epoch 78/1000
# 32/32 - 0s - loss: 0.0992 - accuracy: 0.9648 - val_loss: 0.1025 - val_accuracy: 0.9531 - 58ms/epoch - 2ms/step
# Epoch 79/1000
# 32/32 - 0s - loss: 0.0952 - accuracy: 0.9658 - val_loss: 0.0998 - val_accuracy: 0.9648 - 56ms/epoch - 2ms/step
# Epoch 80/1000
# 32/32 - 0s - loss: 0.0884 - accuracy: 0.9619 - val_loss: 0.1012 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 81/1000
# 32/32 - 0s - loss: 0.0845 - accuracy: 0.9668 - val_loss: 0.1247 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 82/1000
# 32/32 - 0s - loss: 0.0971 - accuracy: 0.9619 - val_loss: 0.1306 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 83/1000
# 32/32 - 0s - loss: 0.0989 - accuracy: 0.9619 - val_loss: 0.1264 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 84/1000
# 32/32 - 0s - loss: 0.0988 - accuracy: 0.9648 - val_loss: 0.0946 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 85/1000
# 32/32 - 0s - loss: 0.0910 - accuracy: 0.9658 - val_loss: 0.0934 - val_accuracy: 0.9688 - 54ms/epoch - 2ms/step
# Epoch 86/1000
# 32/32 - 0s - loss: 0.1003 - accuracy: 0.9648 - val_loss: 0.1170 - val_accuracy: 0.9570 - 62ms/epoch - 2ms/step
# Epoch 87/1000
# 32/32 - 0s - loss: 0.1007 - accuracy: 0.9629 - val_loss: 0.0948 - val_accuracy: 0.9648 - 57ms/epoch - 2ms/step
# Epoch 88/1000
# 32/32 - 0s - loss: 0.0977 - accuracy: 0.9619 - val_loss: 0.0996 - val_accuracy: 0.9492 - 48ms/epoch - 1ms/step
# Epoch 89/1000
# 32/32 - 0s - loss: 0.0903 - accuracy: 0.9678 - val_loss: 0.0863 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 90/1000
# 32/32 - 0s - loss: 0.0946 - accuracy: 0.9600 - val_loss: 0.1083 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 91/1000
# 32/32 - 0s - loss: 0.0904 - accuracy: 0.9648 - val_loss: 0.1142 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 92/1000
# 32/32 - 0s - loss: 0.0875 - accuracy: 0.9717 - val_loss: 0.0973 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 93/1000
# 32/32 - 0s - loss: 0.1124 - accuracy: 0.9600 - val_loss: 0.1107 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 94/1000
# 32/32 - 0s - loss: 0.1032 - accuracy: 0.9629 - val_loss: 0.0867 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 95/1000
# 32/32 - 0s - loss: 0.1019 - accuracy: 0.9619 - val_loss: 0.1186 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 96/1000
# 32/32 - 0s - loss: 0.0887 - accuracy: 0.9648 - val_loss: 0.0842 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 97/1000
# 32/32 - 0s - loss: 0.0915 - accuracy: 0.9639 - val_loss: 0.1326 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 98/1000
# 32/32 - 0s - loss: 0.0919 - accuracy: 0.9658 - val_loss: 0.0867 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 99/1000
# 32/32 - 0s - loss: 0.0863 - accuracy: 0.9658 - val_loss: 0.0935 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 100/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9688 - val_loss: 0.1139 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 101/1000
# 32/32 - 0s - loss: 0.0940 - accuracy: 0.9609 - val_loss: 0.1040 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 102/1000
# 32/32 - 0s - loss: 0.0861 - accuracy: 0.9697 - val_loss: 0.1210 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 103/1000
# 32/32 - 0s - loss: 0.0971 - accuracy: 0.9619 - val_loss: 0.1098 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 104/1000
# 32/32 - 0s - loss: 0.0978 - accuracy: 0.9629 - val_loss: 0.0948 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 105/1000
# 32/32 - 0s - loss: 0.0997 - accuracy: 0.9619 - val_loss: 0.0963 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 106/1000
# 32/32 - 0s - loss: 0.1036 - accuracy: 0.9678 - val_loss: 0.1389 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 107/1000
# 32/32 - 0s - loss: 0.0956 - accuracy: 0.9639 - val_loss: 0.1013 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 108/1000
# 32/32 - 0s - loss: 0.0995 - accuracy: 0.9629 - val_loss: 0.1015 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 109/1000
# 32/32 - 0s - loss: 0.0954 - accuracy: 0.9629 - val_loss: 0.1055 - val_accuracy: 0.9648 - 48ms/epoch - 2ms/step
# Epoch 110/1000
# 32/32 - 0s - loss: 0.0838 - accuracy: 0.9648 - val_loss: 0.0910 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 111/1000
# 32/32 - 0s - loss: 0.1031 - accuracy: 0.9609 - val_loss: 0.1100 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 112/1000
# 32/32 - 0s - loss: 0.0916 - accuracy: 0.9648 - val_loss: 0.0860 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 113/1000
# 32/32 - 0s - loss: 0.0863 - accuracy: 0.9678 - val_loss: 0.0997 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 114/1000
# 32/32 - 0s - loss: 0.0961 - accuracy: 0.9668 - val_loss: 0.0924 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 115/1000
# 32/32 - 0s - loss: 0.0897 - accuracy: 0.9600 - val_loss: 0.1081 - val_accuracy: 0.9688 - 60ms/epoch - 2ms/step
# Epoch 116/1000
# 32/32 - 0s - loss: 0.0916 - accuracy: 0.9658 - val_loss: 0.1416 - val_accuracy: 0.9648 - 48ms/epoch - 2ms/step
# Epoch 117/1000
# 32/32 - 0s - loss: 0.1204 - accuracy: 0.9678 - val_loss: 0.1097 - val_accuracy: 0.9609 - 55ms/epoch - 2ms/step
# Epoch 118/1000
# 32/32 - 0s - loss: 0.0988 - accuracy: 0.9668 - val_loss: 0.1203 - val_accuracy: 0.9453 - 60ms/epoch - 2ms/step
# Epoch 119/1000
# 32/32 - 0s - loss: 0.1178 - accuracy: 0.9629 - val_loss: 0.0935 - val_accuracy: 0.9648 - 62ms/epoch - 2ms/step
# Epoch 120/1000
# 32/32 - 0s - loss: 0.0956 - accuracy: 0.9639 - val_loss: 0.1218 - val_accuracy: 0.9570 - 63ms/epoch - 2ms/step
# Epoch 121/1000
# 32/32 - 0s - loss: 0.1025 - accuracy: 0.9619 - val_loss: 0.1301 - val_accuracy: 0.9492 - 56ms/epoch - 2ms/step
# Epoch 122/1000
# 32/32 - 0s - loss: 0.1015 - accuracy: 0.9629 - val_loss: 0.1136 - val_accuracy: 0.9609 - 52ms/epoch - 2ms/step
# Epoch 123/1000
# 32/32 - 0s - loss: 0.1032 - accuracy: 0.9619 - val_loss: 0.0864 - val_accuracy: 0.9648 - 69ms/epoch - 2ms/step
# Epoch 124/1000
# 32/32 - 0s - loss: 0.0917 - accuracy: 0.9639 - val_loss: 0.0960 - val_accuracy: 0.9609 - 69ms/epoch - 2ms/step
# Epoch 125/1000
# 32/32 - 0s - loss: 0.0920 - accuracy: 0.9658 - val_loss: 0.1066 - val_accuracy: 0.9531 - 54ms/epoch - 2ms/step
# Epoch 126/1000
# 32/32 - 0s - loss: 0.0999 - accuracy: 0.9619 - val_loss: 0.0843 - val_accuracy: 0.9688 - 49ms/epoch - 2ms/step
# Epoch 127/1000
# 32/32 - 0s - loss: 0.0964 - accuracy: 0.9609 - val_loss: 0.0931 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 128/1000
# 32/32 - 0s - loss: 0.0910 - accuracy: 0.9639 - val_loss: 0.1270 - val_accuracy: 0.9453 - 48ms/epoch - 2ms/step
# Epoch 129/1000
# 32/32 - 0s - loss: 0.0961 - accuracy: 0.9639 - val_loss: 0.0921 - val_accuracy: 0.9688 - 48ms/epoch - 1ms/step
# Epoch 130/1000
# 32/32 - 0s - loss: 0.0927 - accuracy: 0.9619 - val_loss: 0.1054 - val_accuracy: 0.9688 - 59ms/epoch - 2ms/step
# Epoch 131/1000
# 32/32 - 0s - loss: 0.0904 - accuracy: 0.9658 - val_loss: 0.0937 - val_accuracy: 0.9570 - 51ms/epoch - 2ms/step
# Epoch 132/1000
# 32/32 - 0s - loss: 0.1026 - accuracy: 0.9639 - val_loss: 0.1068 - val_accuracy: 0.9570 - 77ms/epoch - 2ms/step
# Epoch 133/1000
# 32/32 - 0s - loss: 0.0959 - accuracy: 0.9639 - val_loss: 0.0921 - val_accuracy: 0.9609 - 52ms/epoch - 2ms/step
# Epoch 134/1000
# 32/32 - 0s - loss: 0.0900 - accuracy: 0.9658 - val_loss: 0.1213 - val_accuracy: 0.9453 - 49ms/epoch - 2ms/step
# Epoch 135/1000
# 32/32 - 0s - loss: 0.0942 - accuracy: 0.9639 - val_loss: 0.0945 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 136/1000
# 32/32 - 0s - loss: 0.1027 - accuracy: 0.9609 - val_loss: 0.1180 - val_accuracy: 0.9648 - 48ms/epoch - 2ms/step
# Epoch 137/1000
# 32/32 - 0s - loss: 0.1081 - accuracy: 0.9619 - val_loss: 0.1266 - val_accuracy: 0.9609 - 51ms/epoch - 2ms/step
# Epoch 138/1000
# 32/32 - 0s - loss: 0.1000 - accuracy: 0.9629 - val_loss: 0.0992 - val_accuracy: 0.9531 - 52ms/epoch - 2ms/step
# Epoch 139/1000
# 32/32 - 0s - loss: 0.0922 - accuracy: 0.9668 - val_loss: 0.0947 - val_accuracy: 0.9688 - 77ms/epoch - 2ms/step
# Epoch 140/1000
# 32/32 - 0s - loss: 0.0935 - accuracy: 0.9639 - val_loss: 0.0955 - val_accuracy: 0.9688 - 65ms/epoch - 2ms/step
# Epoch 141/1000
# 32/32 - 0s - loss: 0.0938 - accuracy: 0.9648 - val_loss: 0.1085 - val_accuracy: 0.9492 - 57ms/epoch - 2ms/step
# Epoch 142/1000
# 32/32 - 0s - loss: 0.0906 - accuracy: 0.9639 - val_loss: 0.1322 - val_accuracy: 0.9570 - 62ms/epoch - 2ms/step
# Epoch 143/1000
# 32/32 - 0s - loss: 0.0907 - accuracy: 0.9639 - val_loss: 0.0845 - val_accuracy: 0.9648 - 64ms/epoch - 2ms/step
# Epoch 144/1000
# 32/32 - 0s - loss: 0.0956 - accuracy: 0.9648 - val_loss: 0.1201 - val_accuracy: 0.9648 - 87ms/epoch - 3ms/step
# Epoch 145/1000
# 32/32 - 0s - loss: 0.1016 - accuracy: 0.9541 - val_loss: 0.1325 - val_accuracy: 0.9609 - 58ms/epoch - 2ms/step
# Epoch 146/1000
# 32/32 - 0s - loss: 0.1079 - accuracy: 0.9619 - val_loss: 0.0909 - val_accuracy: 0.9609 - 63ms/epoch - 2ms/step
# Epoch 147/1000
# 32/32 - 0s - loss: 0.1017 - accuracy: 0.9609 - val_loss: 0.0980 - val_accuracy: 0.9648 - 69ms/epoch - 2ms/step
# Epoch 148/1000
# 32/32 - 0s - loss: 0.0947 - accuracy: 0.9658 - val_loss: 0.1008 - val_accuracy: 0.9492 - 67ms/epoch - 2ms/step
# Epoch 149/1000
# 32/32 - 0s - loss: 0.0924 - accuracy: 0.9639 - val_loss: 0.1182 - val_accuracy: 0.9453 - 60ms/epoch - 2ms/step
# Epoch 150/1000
# 32/32 - 0s - loss: 0.0933 - accuracy: 0.9668 - val_loss: 0.1016 - val_accuracy: 0.9648 - 58ms/epoch - 2ms/step
# Epoch 151/1000
# 32/32 - 0s - loss: 0.1020 - accuracy: 0.9570 - val_loss: 0.1475 - val_accuracy: 0.9531 - 53ms/epoch - 2ms/step
# Epoch 152/1000
# 32/32 - 0s - loss: 0.1034 - accuracy: 0.9619 - val_loss: 0.0996 - val_accuracy: 0.9688 - 50ms/epoch - 2ms/step
# Epoch 153/1000
# 32/32 - 0s - loss: 0.0917 - accuracy: 0.9678 - val_loss: 0.1109 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 154/1000
# 32/32 - 0s - loss: 0.0939 - accuracy: 0.9697 - val_loss: 0.0997 - val_accuracy: 0.9531 - 59ms/epoch - 2ms/step
# Epoch 155/1000
# 32/32 - 0s - loss: 0.1125 - accuracy: 0.9531 - val_loss: 0.1027 - val_accuracy: 0.9688 - 62ms/epoch - 2ms/step
# Epoch 156/1000
# 32/32 - 0s - loss: 0.0956 - accuracy: 0.9580 - val_loss: 0.2417 - val_accuracy: 0.9375 - 57ms/epoch - 2ms/step
# Epoch 157/1000
# 32/32 - 0s - loss: 0.1164 - accuracy: 0.9541 - val_loss: 0.1023 - val_accuracy: 0.9492 - 51ms/epoch - 2ms/step
# Epoch 158/1000
# 32/32 - 0s - loss: 0.0875 - accuracy: 0.9629 - val_loss: 0.0892 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 159/1000
# 32/32 - 0s - loss: 0.0943 - accuracy: 0.9668 - val_loss: 0.0925 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 160/1000
# 32/32 - 0s - loss: 0.0942 - accuracy: 0.9639 - val_loss: 0.1292 - val_accuracy: 0.9375 - 47ms/epoch - 1ms/step
# Epoch 161/1000
# 32/32 - 0s - loss: 0.1122 - accuracy: 0.9590 - val_loss: 0.1004 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 162/1000
# 32/32 - 0s - loss: 0.0938 - accuracy: 0.9600 - val_loss: 0.1615 - val_accuracy: 0.9531 - 48ms/epoch - 2ms/step
# Epoch 163/1000
# 32/32 - 0s - loss: 0.1070 - accuracy: 0.9609 - val_loss: 0.1262 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 164/1000
# 32/32 - 0s - loss: 0.0973 - accuracy: 0.9678 - val_loss: 0.1302 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 165/1000
# 32/32 - 0s - loss: 0.0886 - accuracy: 0.9658 - val_loss: 0.0982 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 166/1000
# 32/32 - 0s - loss: 0.0936 - accuracy: 0.9678 - val_loss: 0.1219 - val_accuracy: 0.9531 - 63ms/epoch - 2ms/step
# Epoch 167/1000
# 32/32 - 0s - loss: 0.0962 - accuracy: 0.9648 - val_loss: 0.1017 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 168/1000
# 32/32 - 0s - loss: 0.0933 - accuracy: 0.9629 - val_loss: 0.0928 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 169/1000
# 32/32 - 0s - loss: 0.0941 - accuracy: 0.9600 - val_loss: 0.1004 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 170/1000
# 32/32 - 0s - loss: 0.1056 - accuracy: 0.9609 - val_loss: 0.0987 - val_accuracy: 0.9609 - 48ms/epoch - 1ms/step
# Epoch 171/1000
# 32/32 - 0s - loss: 0.0923 - accuracy: 0.9629 - val_loss: 0.1139 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 172/1000
# 32/32 - 0s - loss: 0.0924 - accuracy: 0.9600 - val_loss: 0.1064 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 173/1000
# 32/32 - 0s - loss: 0.0919 - accuracy: 0.9668 - val_loss: 0.0969 - val_accuracy: 0.9609 - 53ms/epoch - 2ms/step
# Epoch 174/1000
# 32/32 - 0s - loss: 0.1096 - accuracy: 0.9609 - val_loss: 0.1113 - val_accuracy: 0.9609 - 54ms/epoch - 2ms/step
# Epoch 175/1000
# 32/32 - 0s - loss: 0.0936 - accuracy: 0.9590 - val_loss: 0.0917 - val_accuracy: 0.9609 - 52ms/epoch - 2ms/step
# Epoch 176/1000
# 32/32 - 0s - loss: 0.0842 - accuracy: 0.9678 - val_loss: 0.0868 - val_accuracy: 0.9609 - 77ms/epoch - 2ms/step
# Epoch 177/1000
# 32/32 - 0s - loss: 0.0878 - accuracy: 0.9629 - val_loss: 0.1046 - val_accuracy: 0.9609 - 67ms/epoch - 2ms/step
# Epoch 178/1000
# 32/32 - 0s - loss: 0.0934 - accuracy: 0.9609 - val_loss: 0.1142 - val_accuracy: 0.9492 - 56ms/epoch - 2ms/step
# Epoch 179/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9648 - val_loss: 0.0977 - val_accuracy: 0.9570 - 50ms/epoch - 2ms/step
# Epoch 180/1000
# 32/32 - 0s - loss: 0.0895 - accuracy: 0.9648 - val_loss: 0.1294 - val_accuracy: 0.9453 - 52ms/epoch - 2ms/step
# Epoch 181/1000
# 32/32 - 0s - loss: 0.0907 - accuracy: 0.9629 - val_loss: 0.1258 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 182/1000
# 32/32 - 0s - loss: 0.0966 - accuracy: 0.9609 - val_loss: 0.1138 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 183/1000
# 32/32 - 0s - loss: 0.0993 - accuracy: 0.9678 - val_loss: 0.0951 - val_accuracy: 0.9492 - 51ms/epoch - 2ms/step
# Epoch 184/1000
# 32/32 - 0s - loss: 0.0926 - accuracy: 0.9688 - val_loss: 0.0945 - val_accuracy: 0.9648 - 51ms/epoch - 2ms/step
# Epoch 185/1000
# 32/32 - 0s - loss: 0.1022 - accuracy: 0.9600 - val_loss: 0.1018 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 186/1000
# 32/32 - 0s - loss: 0.1034 - accuracy: 0.9639 - val_loss: 0.1077 - val_accuracy: 0.9688 - 45ms/epoch - 1ms/step
# Epoch 187/1000
# 32/32 - 0s - loss: 0.1009 - accuracy: 0.9629 - val_loss: 0.1145 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 188/1000
# 32/32 - 0s - loss: 0.0916 - accuracy: 0.9658 - val_loss: 0.1063 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 189/1000
# 32/32 - 0s - loss: 0.0998 - accuracy: 0.9600 - val_loss: 0.0948 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 190/1000
# 32/32 - 0s - loss: 0.0960 - accuracy: 0.9619 - val_loss: 0.1268 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 191/1000
# 32/32 - 0s - loss: 0.0998 - accuracy: 0.9609 - val_loss: 0.0924 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 192/1000
# 32/32 - 0s - loss: 0.0962 - accuracy: 0.9648 - val_loss: 0.1290 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 193/1000
# 32/32 - 0s - loss: 0.0955 - accuracy: 0.9639 - val_loss: 0.1112 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 194/1000
# 32/32 - 0s - loss: 0.0900 - accuracy: 0.9678 - val_loss: 0.1000 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 195/1000
# 32/32 - 0s - loss: 0.0945 - accuracy: 0.9619 - val_loss: 0.1119 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 196/1000
# 32/32 - 0s - loss: 0.0936 - accuracy: 0.9648 - val_loss: 0.0896 - val_accuracy: 0.9688 - 55ms/epoch - 2ms/step
# Epoch 197/1000
# 32/32 - 0s - loss: 0.0904 - accuracy: 0.9688 - val_loss: 0.1048 - val_accuracy: 0.9570 - 78ms/epoch - 2ms/step
# Epoch 198/1000
# 32/32 - 0s - loss: 0.0914 - accuracy: 0.9609 - val_loss: 0.1066 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 199/1000
# 32/32 - 0s - loss: 0.0960 - accuracy: 0.9639 - val_loss: 0.0999 - val_accuracy: 0.9570 - 45ms/epoch - 1ms/step
# Epoch 200/1000
# 32/32 - 0s - loss: 0.1117 - accuracy: 0.9619 - val_loss: 0.0892 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 201/1000
# 32/32 - 0s - loss: 0.0975 - accuracy: 0.9570 - val_loss: 0.1154 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 202/1000
# 32/32 - 0s - loss: 0.1058 - accuracy: 0.9648 - val_loss: 0.1515 - val_accuracy: 0.9453 - 54ms/epoch - 2ms/step
# Epoch 203/1000
# 32/32 - 0s - loss: 0.0969 - accuracy: 0.9639 - val_loss: 0.1000 - val_accuracy: 0.9570 - 56ms/epoch - 2ms/step
# Epoch 204/1000
# 32/32 - 0s - loss: 0.0898 - accuracy: 0.9658 - val_loss: 0.1027 - val_accuracy: 0.9648 - 53ms/epoch - 2ms/step
# Epoch 205/1000
# 32/32 - 0s - loss: 0.0874 - accuracy: 0.9678 - val_loss: 0.1060 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 206/1000
# 32/32 - 0s - loss: 0.1001 - accuracy: 0.9609 - val_loss: 0.0910 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 207/1000
# 32/32 - 0s - loss: 0.0938 - accuracy: 0.9648 - val_loss: 0.0935 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 208/1000
# 32/32 - 0s - loss: 0.1027 - accuracy: 0.9629 - val_loss: 0.0996 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 209/1000
# 32/32 - 0s - loss: 0.1023 - accuracy: 0.9531 - val_loss: 0.0901 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 210/1000
# 32/32 - 0s - loss: 0.1008 - accuracy: 0.9629 - val_loss: 0.1583 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 211/1000
# 32/32 - 0s - loss: 0.0944 - accuracy: 0.9658 - val_loss: 0.0986 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 212/1000
# 32/32 - 0s - loss: 0.0977 - accuracy: 0.9639 - val_loss: 0.1079 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 213/1000
# 32/32 - 0s - loss: 0.0911 - accuracy: 0.9629 - val_loss: 0.0961 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 214/1000
# 32/32 - 0s - loss: 0.0955 - accuracy: 0.9629 - val_loss: 0.1031 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 215/1000
# 32/32 - 0s - loss: 0.0921 - accuracy: 0.9678 - val_loss: 0.1426 - val_accuracy: 0.9414 - 45ms/epoch - 1ms/step
# Epoch 216/1000
# 32/32 - 0s - loss: 0.1065 - accuracy: 0.9629 - val_loss: 0.1237 - val_accuracy: 0.9609 - 44ms/epoch - 1ms/step
# Epoch 217/1000
# 32/32 - 0s - loss: 0.0991 - accuracy: 0.9619 - val_loss: 0.1126 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 218/1000
# 32/32 - 0s - loss: 0.0929 - accuracy: 0.9668 - val_loss: 0.1104 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 219/1000
# 32/32 - 0s - loss: 0.0917 - accuracy: 0.9629 - val_loss: 0.0980 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 220/1000
# 32/32 - 0s - loss: 0.0899 - accuracy: 0.9658 - val_loss: 0.1104 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 221/1000
# 32/32 - 0s - loss: 0.0935 - accuracy: 0.9619 - val_loss: 0.1104 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 222/1000
# 32/32 - 0s - loss: 0.0985 - accuracy: 0.9619 - val_loss: 0.0872 - val_accuracy: 0.9727 - 47ms/epoch - 1ms/step
# Epoch 223/1000
# 32/32 - 0s - loss: 0.0930 - accuracy: 0.9609 - val_loss: 0.0973 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 224/1000
# 32/32 - 0s - loss: 0.0965 - accuracy: 0.9688 - val_loss: 0.1011 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 225/1000
# 32/32 - 0s - loss: 0.0941 - accuracy: 0.9658 - val_loss: 0.1009 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 226/1000
# 32/32 - 0s - loss: 0.0976 - accuracy: 0.9629 - val_loss: 0.1127 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 227/1000
# 32/32 - 0s - loss: 0.0935 - accuracy: 0.9688 - val_loss: 0.1023 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 228/1000
# 32/32 - 0s - loss: 0.0927 - accuracy: 0.9658 - val_loss: 0.0969 - val_accuracy: 0.9688 - 51ms/epoch - 2ms/step
# Epoch 229/1000
# 32/32 - 0s - loss: 0.0913 - accuracy: 0.9668 - val_loss: 0.1278 - val_accuracy: 0.9492 - 54ms/epoch - 2ms/step
# Epoch 230/1000
# 32/32 - 0s - loss: 0.0958 - accuracy: 0.9639 - val_loss: 0.0859 - val_accuracy: 0.9609 - 54ms/epoch - 2ms/step
# Epoch 231/1000
# 32/32 - 0s - loss: 0.0907 - accuracy: 0.9629 - val_loss: 0.1090 - val_accuracy: 0.9648 - 77ms/epoch - 2ms/step
# Epoch 232/1000
# 32/32 - 0s - loss: 0.0901 - accuracy: 0.9658 - val_loss: 0.0839 - val_accuracy: 0.9570 - 55ms/epoch - 2ms/step
# Epoch 233/1000
# 32/32 - 0s - loss: 0.1043 - accuracy: 0.9590 - val_loss: 0.1063 - val_accuracy: 0.9609 - 57ms/epoch - 2ms/step
# Epoch 234/1000
# 32/32 - 0s - loss: 0.0998 - accuracy: 0.9648 - val_loss: 0.1204 - val_accuracy: 0.9570 - 54ms/epoch - 2ms/step
# Epoch 235/1000
# 32/32 - 0s - loss: 0.1085 - accuracy: 0.9619 - val_loss: 0.0923 - val_accuracy: 0.9648 - 53ms/epoch - 2ms/step
# Epoch 236/1000
# 32/32 - 0s - loss: 0.1013 - accuracy: 0.9619 - val_loss: 0.1062 - val_accuracy: 0.9609 - 50ms/epoch - 2ms/step
# Epoch 237/1000
# 32/32 - 0s - loss: 0.1062 - accuracy: 0.9600 - val_loss: 0.1006 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 238/1000
# 32/32 - 0s - loss: 0.0953 - accuracy: 0.9678 - val_loss: 0.1071 - val_accuracy: 0.9531 - 50ms/epoch - 2ms/step
# Epoch 239/1000
# 32/32 - 0s - loss: 0.1027 - accuracy: 0.9639 - val_loss: 0.0966 - val_accuracy: 0.9648 - 53ms/epoch - 2ms/step
# Epoch 240/1000
# 32/32 - 0s - loss: 0.0974 - accuracy: 0.9590 - val_loss: 0.1138 - val_accuracy: 0.9648 - 58ms/epoch - 2ms/step
# Epoch 241/1000
# 32/32 - 0s - loss: 0.0992 - accuracy: 0.9668 - val_loss: 0.0937 - val_accuracy: 0.9609 - 54ms/epoch - 2ms/step
# Epoch 242/1000
# 32/32 - 0s - loss: 0.0979 - accuracy: 0.9619 - val_loss: 0.1121 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 243/1000
# 32/32 - 0s - loss: 0.0922 - accuracy: 0.9658 - val_loss: 0.1083 - val_accuracy: 0.9570 - 48ms/epoch - 1ms/step
# Epoch 244/1000
# 32/32 - 0s - loss: 0.0980 - accuracy: 0.9619 - val_loss: 0.1141 - val_accuracy: 0.9453 - 57ms/epoch - 2ms/step
# Epoch 245/1000
# 32/32 - 0s - loss: 0.0952 - accuracy: 0.9658 - val_loss: 0.1247 - val_accuracy: 0.9609 - 51ms/epoch - 2ms/step
# Epoch 246/1000
# 32/32 - 0s - loss: 0.1003 - accuracy: 0.9609 - val_loss: 0.0792 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 247/1000
# 32/32 - 0s - loss: 0.0862 - accuracy: 0.9678 - val_loss: 0.1288 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 248/1000
# 32/32 - 0s - loss: 0.0861 - accuracy: 0.9688 - val_loss: 0.1033 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 249/1000
# 32/32 - 0s - loss: 0.0952 - accuracy: 0.9590 - val_loss: 0.0997 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 250/1000
# 32/32 - 0s - loss: 0.0954 - accuracy: 0.9619 - val_loss: 0.1274 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 251/1000
# 32/32 - 0s - loss: 0.0927 - accuracy: 0.9639 - val_loss: 0.0983 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 252/1000
# 32/32 - 0s - loss: 0.1042 - accuracy: 0.9639 - val_loss: 0.1128 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 253/1000
# 32/32 - 0s - loss: 0.1160 - accuracy: 0.9551 - val_loss: 0.1077 - val_accuracy: 0.9688 - 45ms/epoch - 1ms/step
# Epoch 254/1000
# 32/32 - 0s - loss: 0.0880 - accuracy: 0.9678 - val_loss: 0.1062 - val_accuracy: 0.9609 - 53ms/epoch - 2ms/step
# Epoch 255/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9658 - val_loss: 0.0970 - val_accuracy: 0.9648 - 48ms/epoch - 2ms/step
# Epoch 256/1000
# 32/32 - 0s - loss: 0.0872 - accuracy: 0.9668 - val_loss: 0.1353 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 257/1000
# 32/32 - 0s - loss: 0.0863 - accuracy: 0.9668 - val_loss: 0.0937 - val_accuracy: 0.9648 - 52ms/epoch - 2ms/step
# Epoch 258/1000
# 32/32 - 0s - loss: 0.0999 - accuracy: 0.9609 - val_loss: 0.1096 - val_accuracy: 0.9531 - 53ms/epoch - 2ms/step
# Epoch 259/1000
# 32/32 - 0s - loss: 0.0920 - accuracy: 0.9619 - val_loss: 0.0954 - val_accuracy: 0.9570 - 62ms/epoch - 2ms/step
# Epoch 260/1000
# 32/32 - 0s - loss: 0.1140 - accuracy: 0.9600 - val_loss: 0.0960 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 261/1000
# 32/32 - 0s - loss: 0.0956 - accuracy: 0.9619 - val_loss: 0.0942 - val_accuracy: 0.9531 - 55ms/epoch - 2ms/step
# Epoch 262/1000
# 32/32 - 0s - loss: 0.0957 - accuracy: 0.9600 - val_loss: 0.1220 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 263/1000
# 32/32 - 0s - loss: 0.0958 - accuracy: 0.9678 - val_loss: 0.1072 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 264/1000
# 32/32 - 0s - loss: 0.0965 - accuracy: 0.9648 - val_loss: 0.1039 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 265/1000
# 32/32 - 0s - loss: 0.0930 - accuracy: 0.9629 - val_loss: 0.1088 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 266/1000
# 32/32 - 0s - loss: 0.1029 - accuracy: 0.9648 - val_loss: 0.0982 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 267/1000
# 32/32 - 0s - loss: 0.0927 - accuracy: 0.9658 - val_loss: 0.1152 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 268/1000
# 32/32 - 0s - loss: 0.0955 - accuracy: 0.9629 - val_loss: 0.1581 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 269/1000
# 32/32 - 0s - loss: 0.0945 - accuracy: 0.9629 - val_loss: 0.0952 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 270/1000
# 32/32 - 0s - loss: 0.0911 - accuracy: 0.9678 - val_loss: 0.1100 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 271/1000
# 32/32 - 0s - loss: 0.1009 - accuracy: 0.9580 - val_loss: 0.1132 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 272/1000
# 32/32 - 0s - loss: 0.1283 - accuracy: 0.9521 - val_loss: 0.1037 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 273/1000
# 32/32 - 0s - loss: 0.0984 - accuracy: 0.9600 - val_loss: 0.0932 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 274/1000
# 32/32 - 0s - loss: 0.1002 - accuracy: 0.9600 - val_loss: 0.1086 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 275/1000
# 32/32 - 0s - loss: 0.0944 - accuracy: 0.9658 - val_loss: 0.1130 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 276/1000
# 32/32 - 0s - loss: 0.1001 - accuracy: 0.9648 - val_loss: 0.1169 - val_accuracy: 0.9492 - 52ms/epoch - 2ms/step
# Epoch 277/1000
# 32/32 - 0s - loss: 0.0910 - accuracy: 0.9629 - val_loss: 0.0877 - val_accuracy: 0.9609 - 52ms/epoch - 2ms/step
# Epoch 278/1000
# 32/32 - 0s - loss: 0.0954 - accuracy: 0.9609 - val_loss: 0.1225 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 279/1000
# 32/32 - 0s - loss: 0.1066 - accuracy: 0.9600 - val_loss: 0.1076 - val_accuracy: 0.9648 - 48ms/epoch - 1ms/step
# Epoch 280/1000
# 32/32 - 0s - loss: 0.1044 - accuracy: 0.9580 - val_loss: 0.1108 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 281/1000
# 32/32 - 0s - loss: 0.1032 - accuracy: 0.9580 - val_loss: 0.1012 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 282/1000
# 32/32 - 0s - loss: 0.0957 - accuracy: 0.9658 - val_loss: 0.1196 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 283/1000
# 32/32 - 0s - loss: 0.0876 - accuracy: 0.9639 - val_loss: 0.1168 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 284/1000
# 32/32 - 0s - loss: 0.0961 - accuracy: 0.9600 - val_loss: 0.1277 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 285/1000
# 32/32 - 0s - loss: 0.0950 - accuracy: 0.9639 - val_loss: 0.0911 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 286/1000
# 32/32 - 0s - loss: 0.0900 - accuracy: 0.9658 - val_loss: 0.1112 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 287/1000
# 32/32 - 0s - loss: 0.0967 - accuracy: 0.9629 - val_loss: 0.1073 - val_accuracy: 0.9570 - 58ms/epoch - 2ms/step
# Epoch 288/1000
# 32/32 - 0s - loss: 0.1066 - accuracy: 0.9609 - val_loss: 0.0868 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 289/1000
# 32/32 - 0s - loss: 0.0876 - accuracy: 0.9658 - val_loss: 0.1001 - val_accuracy: 0.9688 - 45ms/epoch - 1ms/step
# Epoch 290/1000
# 32/32 - 0s - loss: 0.0970 - accuracy: 0.9619 - val_loss: 0.0890 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 291/1000
# 32/32 - 0s - loss: 0.1071 - accuracy: 0.9600 - val_loss: 0.1299 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 292/1000
# 32/32 - 0s - loss: 0.1064 - accuracy: 0.9551 - val_loss: 0.1040 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 293/1000
# 32/32 - 0s - loss: 0.0962 - accuracy: 0.9629 - val_loss: 0.0932 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 294/1000
# 32/32 - 0s - loss: 0.0874 - accuracy: 0.9639 - val_loss: 0.1073 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 295/1000
# 32/32 - 0s - loss: 0.0857 - accuracy: 0.9648 - val_loss: 0.1104 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 296/1000
# 32/32 - 0s - loss: 0.0983 - accuracy: 0.9648 - val_loss: 0.1379 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 297/1000
# 32/32 - 0s - loss: 0.1017 - accuracy: 0.9619 - val_loss: 0.1122 - val_accuracy: 0.9688 - 45ms/epoch - 1ms/step
# Epoch 298/1000
# 32/32 - 0s - loss: 0.0969 - accuracy: 0.9629 - val_loss: 0.0906 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 299/1000
# 32/32 - 0s - loss: 0.0903 - accuracy: 0.9648 - val_loss: 0.1022 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 300/1000
# 32/32 - 0s - loss: 0.0871 - accuracy: 0.9639 - val_loss: 0.1079 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 301/1000
# 32/32 - 0s - loss: 0.0970 - accuracy: 0.9609 - val_loss: 0.1497 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 302/1000
# 32/32 - 0s - loss: 0.1051 - accuracy: 0.9570 - val_loss: 0.0953 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 303/1000
# 32/32 - 0s - loss: 0.0907 - accuracy: 0.9678 - val_loss: 0.0978 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 304/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9668 - val_loss: 0.0960 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 305/1000
# 32/32 - 0s - loss: 0.0977 - accuracy: 0.9668 - val_loss: 0.1197 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 306/1000
# 32/32 - 0s - loss: 0.0955 - accuracy: 0.9609 - val_loss: 0.1165 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 307/1000
# 32/32 - 0s - loss: 0.0874 - accuracy: 0.9668 - val_loss: 0.1042 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 308/1000
# 32/32 - 0s - loss: 0.1002 - accuracy: 0.9609 - val_loss: 0.0911 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 309/1000
# 32/32 - 0s - loss: 0.0933 - accuracy: 0.9639 - val_loss: 0.1328 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 310/1000
# 32/32 - 0s - loss: 0.0966 - accuracy: 0.9658 - val_loss: 0.0981 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 311/1000
# 32/32 - 0s - loss: 0.0898 - accuracy: 0.9717 - val_loss: 0.0940 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 312/1000
# 32/32 - 0s - loss: 0.0971 - accuracy: 0.9619 - val_loss: 0.1055 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 313/1000
# 32/32 - 0s - loss: 0.1002 - accuracy: 0.9570 - val_loss: 0.1122 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 314/1000
# 32/32 - 0s - loss: 0.1011 - accuracy: 0.9619 - val_loss: 0.1263 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 315/1000
# 32/32 - 0s - loss: 0.0933 - accuracy: 0.9648 - val_loss: 0.1084 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 316/1000
# 32/32 - 0s - loss: 0.0932 - accuracy: 0.9629 - val_loss: 0.0927 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 317/1000
# 32/32 - 0s - loss: 0.0931 - accuracy: 0.9639 - val_loss: 0.0883 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 318/1000
# 32/32 - 0s - loss: 0.0869 - accuracy: 0.9648 - val_loss: 0.1044 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 319/1000
# 32/32 - 0s - loss: 0.0914 - accuracy: 0.9639 - val_loss: 0.0859 - val_accuracy: 0.9648 - 61ms/epoch - 2ms/step
# Epoch 320/1000
# 32/32 - 0s - loss: 0.0944 - accuracy: 0.9648 - val_loss: 0.1260 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 321/1000
# 32/32 - 0s - loss: 0.0978 - accuracy: 0.9600 - val_loss: 0.1121 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 322/1000
# 32/32 - 0s - loss: 0.0927 - accuracy: 0.9658 - val_loss: 0.1141 - val_accuracy: 0.9492 - 45ms/epoch - 1ms/step
# Epoch 323/1000
# 32/32 - 0s - loss: 0.0913 - accuracy: 0.9639 - val_loss: 0.0944 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 324/1000
# 32/32 - 0s - loss: 0.1001 - accuracy: 0.9600 - val_loss: 0.1003 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 325/1000
# 32/32 - 0s - loss: 0.0937 - accuracy: 0.9658 - val_loss: 0.1009 - val_accuracy: 0.9570 - 48ms/epoch - 1ms/step
# Epoch 326/1000
# 32/32 - 0s - loss: 0.1002 - accuracy: 0.9600 - val_loss: 0.1060 - val_accuracy: 0.9414 - 48ms/epoch - 1ms/step
# Epoch 327/1000
# 32/32 - 0s - loss: 0.0905 - accuracy: 0.9658 - val_loss: 0.0912 - val_accuracy: 0.9609 - 54ms/epoch - 2ms/step
# Epoch 328/1000
# 32/32 - 0s - loss: 0.0970 - accuracy: 0.9629 - val_loss: 0.0948 - val_accuracy: 0.9609 - 49ms/epoch - 2ms/step
# Epoch 329/1000
# 32/32 - 0s - loss: 0.0885 - accuracy: 0.9648 - val_loss: 0.1171 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 330/1000
# 32/32 - 0s - loss: 0.0909 - accuracy: 0.9648 - val_loss: 0.1062 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 331/1000
# 32/32 - 0s - loss: 0.0955 - accuracy: 0.9639 - val_loss: 0.1065 - val_accuracy: 0.9688 - 45ms/epoch - 1ms/step
# Epoch 332/1000
# 32/32 - 0s - loss: 0.1054 - accuracy: 0.9619 - val_loss: 0.1011 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 333/1000
# 32/32 - 0s - loss: 0.1094 - accuracy: 0.9590 - val_loss: 0.0886 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 334/1000
# 32/32 - 0s - loss: 0.0918 - accuracy: 0.9639 - val_loss: 0.1819 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 335/1000
# 32/32 - 0s - loss: 0.0918 - accuracy: 0.9668 - val_loss: 0.1026 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 336/1000
# 32/32 - 0s - loss: 0.0972 - accuracy: 0.9600 - val_loss: 0.1001 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 337/1000
# 32/32 - 0s - loss: 0.0965 - accuracy: 0.9639 - val_loss: 0.1344 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 338/1000
# 32/32 - 0s - loss: 0.0902 - accuracy: 0.9648 - val_loss: 0.1451 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 339/1000
# 32/32 - 0s - loss: 0.0941 - accuracy: 0.9639 - val_loss: 0.1019 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 340/1000
# 32/32 - 0s - loss: 0.1033 - accuracy: 0.9629 - val_loss: 0.1052 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 341/1000
# 32/32 - 0s - loss: 0.0888 - accuracy: 0.9629 - val_loss: 0.1308 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 342/1000
# 32/32 - 0s - loss: 0.0988 - accuracy: 0.9658 - val_loss: 0.0920 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 343/1000
# 32/32 - 0s - loss: 0.1043 - accuracy: 0.9580 - val_loss: 0.1128 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 344/1000
# 32/32 - 0s - loss: 0.0953 - accuracy: 0.9629 - val_loss: 0.1005 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 345/1000
# 32/32 - 0s - loss: 0.0963 - accuracy: 0.9629 - val_loss: 0.0895 - val_accuracy: 0.9609 - 54ms/epoch - 2ms/step
# Epoch 346/1000
# 32/32 - 0s - loss: 0.0954 - accuracy: 0.9639 - val_loss: 0.0886 - val_accuracy: 0.9609 - 50ms/epoch - 2ms/step
# Epoch 347/1000
# 32/32 - 0s - loss: 0.0876 - accuracy: 0.9697 - val_loss: 0.0993 - val_accuracy: 0.9570 - 49ms/epoch - 2ms/step
# Epoch 348/1000
# 32/32 - 0s - loss: 0.0985 - accuracy: 0.9600 - val_loss: 0.1243 - val_accuracy: 0.9453 - 48ms/epoch - 1ms/step
# Epoch 349/1000
# 32/32 - 0s - loss: 0.1014 - accuracy: 0.9629 - val_loss: 0.1481 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 350/1000
# 32/32 - 0s - loss: 0.1132 - accuracy: 0.9590 - val_loss: 0.1051 - val_accuracy: 0.9531 - 61ms/epoch - 2ms/step
# Epoch 351/1000
# 32/32 - 0s - loss: 0.0878 - accuracy: 0.9629 - val_loss: 0.1299 - val_accuracy: 0.9492 - 45ms/epoch - 1ms/step
# Epoch 352/1000
# 32/32 - 0s - loss: 0.0945 - accuracy: 0.9639 - val_loss: 0.1069 - val_accuracy: 0.9727 - 45ms/epoch - 1ms/step
# Epoch 353/1000
# 32/32 - 0s - loss: 0.1006 - accuracy: 0.9590 - val_loss: 0.0873 - val_accuracy: 0.9648 - 50ms/epoch - 2ms/step
# Epoch 354/1000
# 32/32 - 0s - loss: 0.1058 - accuracy: 0.9541 - val_loss: 0.1002 - val_accuracy: 0.9531 - 50ms/epoch - 2ms/step
# Epoch 355/1000
# 32/32 - 0s - loss: 0.0951 - accuracy: 0.9619 - val_loss: 0.0963 - val_accuracy: 0.9648 - 53ms/epoch - 2ms/step
# Epoch 356/1000
# 32/32 - 0s - loss: 0.1023 - accuracy: 0.9590 - val_loss: 0.0919 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 357/1000
# 32/32 - 0s - loss: 0.1040 - accuracy: 0.9570 - val_loss: 0.0859 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 358/1000
# 32/32 - 0s - loss: 0.1137 - accuracy: 0.9580 - val_loss: 0.2218 - val_accuracy: 0.9297 - 46ms/epoch - 1ms/step
# Epoch 359/1000
# 32/32 - 0s - loss: 0.1198 - accuracy: 0.9531 - val_loss: 0.1036 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 360/1000
# 32/32 - 0s - loss: 0.1240 - accuracy: 0.9570 - val_loss: 0.1205 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 361/1000
# 32/32 - 0s - loss: 0.1064 - accuracy: 0.9668 - val_loss: 0.0939 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 362/1000
# 32/32 - 0s - loss: 0.0973 - accuracy: 0.9668 - val_loss: 0.1613 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 363/1000
# 32/32 - 0s - loss: 0.1217 - accuracy: 0.9541 - val_loss: 0.1044 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 364/1000
# 32/32 - 0s - loss: 0.1099 - accuracy: 0.9600 - val_loss: 0.1265 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 365/1000
# 32/32 - 0s - loss: 0.0935 - accuracy: 0.9678 - val_loss: 0.1145 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 366/1000
# 32/32 - 0s - loss: 0.1006 - accuracy: 0.9619 - val_loss: 0.1529 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 367/1000
# 32/32 - 0s - loss: 0.0967 - accuracy: 0.9619 - val_loss: 0.1081 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 368/1000
# 32/32 - 0s - loss: 0.0923 - accuracy: 0.9648 - val_loss: 0.1159 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 369/1000
# 32/32 - 0s - loss: 0.0971 - accuracy: 0.9629 - val_loss: 0.1333 - val_accuracy: 0.9375 - 45ms/epoch - 1ms/step
# Epoch 370/1000
# 32/32 - 0s - loss: 0.0902 - accuracy: 0.9639 - val_loss: 0.1159 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 371/1000
# 32/32 - 0s - loss: 0.0877 - accuracy: 0.9658 - val_loss: 0.0967 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 372/1000
# 32/32 - 0s - loss: 0.0931 - accuracy: 0.9688 - val_loss: 0.1138 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 373/1000
# 32/32 - 0s - loss: 0.0955 - accuracy: 0.9609 - val_loss: 0.1048 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 374/1000
# ...
# 32/32 - 0s - loss: 0.0828 - accuracy: 0.9697 - val_loss: 0.1002 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 875/1000
# 32/32 - 0s - loss: 0.0827 - accuracy: 0.9678 - val_loss: 0.0949 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 876/1000
# 32/32 - 0s - loss: 0.0884 - accuracy: 0.9639 - val_loss: 0.0981 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 877/1000
# 32/32 - 0s - loss: 0.0812 - accuracy: 0.9697 - val_loss: 0.0990 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 878/1000
# 32/32 - 0s - loss: 0.0944 - accuracy: 0.9629 - val_loss: 0.0999 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 879/1000
# 32/32 - 0s - loss: 0.0789 - accuracy: 0.9697 - val_loss: 0.1159 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 880/1000
# 32/32 - 0s - loss: 0.0932 - accuracy: 0.9629 - val_loss: 0.1625 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 881/1000
# 32/32 - 0s - loss: 0.0873 - accuracy: 0.9668 - val_loss: 0.1054 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 882/1000
# 32/32 - 0s - loss: 0.0857 - accuracy: 0.9678 - val_loss: 0.0976 - val_accuracy: 0.9492 - 48ms/epoch - 1ms/step
# Epoch 883/1000
# 32/32 - 0s - loss: 0.0827 - accuracy: 0.9658 - val_loss: 0.1050 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 884/1000
# 32/32 - 0s - loss: 0.0868 - accuracy: 0.9668 - val_loss: 0.0910 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 885/1000
# 32/32 - 0s - loss: 0.0881 - accuracy: 0.9688 - val_loss: 0.1062 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 886/1000
# 32/32 - 0s - loss: 0.0885 - accuracy: 0.9668 - val_loss: 0.1326 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 887/1000
# 32/32 - 0s - loss: 0.0852 - accuracy: 0.9648 - val_loss: 0.0962 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 888/1000
# 32/32 - 0s - loss: 0.0815 - accuracy: 0.9688 - val_loss: 0.1057 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 889/1000
# 32/32 - 0s - loss: 0.0873 - accuracy: 0.9658 - val_loss: 0.1130 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 890/1000
# 32/32 - 0s - loss: 0.0888 - accuracy: 0.9619 - val_loss: 0.1099 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 891/1000
# 32/32 - 0s - loss: 0.0879 - accuracy: 0.9639 - val_loss: 0.1477 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 892/1000
# 32/32 - 0s - loss: 0.0936 - accuracy: 0.9678 - val_loss: 0.0898 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 893/1000
# 32/32 - 0s - loss: 0.0983 - accuracy: 0.9629 - val_loss: 0.0928 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 894/1000
# 32/32 - 0s - loss: 0.1006 - accuracy: 0.9658 - val_loss: 0.1083 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 895/1000
# 32/32 - 0s - loss: 0.0992 - accuracy: 0.9609 - val_loss: 0.1261 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 896/1000
# 32/32 - 0s - loss: 0.0828 - accuracy: 0.9648 - val_loss: 0.0971 - val_accuracy: 0.9609 - 59ms/epoch - 2ms/step
# Epoch 897/1000
# 32/32 - 0s - loss: 0.0778 - accuracy: 0.9707 - val_loss: 0.1383 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 898/1000
# 32/32 - 0s - loss: 0.1259 - accuracy: 0.9512 - val_loss: 0.1081 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 899/1000
# 32/32 - 0s - loss: 0.0900 - accuracy: 0.9688 - val_loss: 0.0859 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 900/1000
# 32/32 - 0s - loss: 0.0845 - accuracy: 0.9648 - val_loss: 0.1510 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 901/1000
# 32/32 - 0s - loss: 0.0942 - accuracy: 0.9619 - val_loss: 0.0943 - val_accuracy: 0.9531 - 48ms/epoch - 2ms/step
# Epoch 902/1000
# 32/32 - 0s - loss: 0.0908 - accuracy: 0.9668 - val_loss: 0.1151 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 903/1000
# 32/32 - 0s - loss: 0.0838 - accuracy: 0.9678 - val_loss: 0.0935 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 904/1000
# 32/32 - 0s - loss: 0.0835 - accuracy: 0.9678 - val_loss: 0.1111 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 905/1000
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9619 - val_loss: 0.0981 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 906/1000
# 32/32 - 0s - loss: 0.0930 - accuracy: 0.9619 - val_loss: 0.0983 - val_accuracy: 0.9727 - 46ms/epoch - 1ms/step
# Epoch 907/1000
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9668 - val_loss: 0.1670 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 908/1000
# 32/32 - 0s - loss: 0.0888 - accuracy: 0.9717 - val_loss: 0.0940 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 909/1000
# 32/32 - 0s - loss: 0.0851 - accuracy: 0.9600 - val_loss: 0.1431 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 910/1000
# 32/32 - 0s - loss: 0.0854 - accuracy: 0.9609 - val_loss: 0.1322 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 911/1000
# 32/32 - 0s - loss: 0.1016 - accuracy: 0.9658 - val_loss: 0.1009 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 912/1000
# 32/32 - 0s - loss: 0.0881 - accuracy: 0.9619 - val_loss: 0.0969 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 913/1000
# 32/32 - 0s - loss: 0.0801 - accuracy: 0.9688 - val_loss: 0.1114 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 914/1000
# 32/32 - 0s - loss: 0.0810 - accuracy: 0.9668 - val_loss: 0.1495 - val_accuracy: 0.9453 - 52ms/epoch - 2ms/step
# Epoch 915/1000
# 32/32 - 0s - loss: 0.0869 - accuracy: 0.9668 - val_loss: 0.1038 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 916/1000
# 32/32 - 0s - loss: 0.0832 - accuracy: 0.9668 - val_loss: 0.1055 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 917/1000
# 32/32 - 0s - loss: 0.0913 - accuracy: 0.9658 - val_loss: 0.1456 - val_accuracy: 0.9453 - 47ms/epoch - 1ms/step
# Epoch 918/1000
# 32/32 - 0s - loss: 0.0808 - accuracy: 0.9746 - val_loss: 0.0982 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 919/1000
# 32/32 - 0s - loss: 0.0834 - accuracy: 0.9678 - val_loss: 0.0990 - val_accuracy: 0.9648 - 60ms/epoch - 2ms/step
# Epoch 920/1000
# 32/32 - 0s - loss: 0.0866 - accuracy: 0.9658 - val_loss: 0.0942 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 921/1000
# 32/32 - 0s - loss: 0.0878 - accuracy: 0.9678 - val_loss: 0.0922 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 922/1000
# 32/32 - 0s - loss: 0.0842 - accuracy: 0.9678 - val_loss: 0.1199 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 923/1000
# 32/32 - 0s - loss: 0.0850 - accuracy: 0.9668 - val_loss: 0.1185 - val_accuracy: 0.9492 - 45ms/epoch - 1ms/step
# Epoch 924/1000
# 32/32 - 0s - loss: 0.0900 - accuracy: 0.9658 - val_loss: 0.0923 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 925/1000
# 32/32 - 0s - loss: 0.0836 - accuracy: 0.9688 - val_loss: 0.1168 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 926/1000
# 32/32 - 0s - loss: 0.0895 - accuracy: 0.9678 - val_loss: 0.1109 - val_accuracy: 0.9531 - 50ms/epoch - 2ms/step
# Epoch 927/1000
# 32/32 - 0s - loss: 0.0870 - accuracy: 0.9658 - val_loss: 0.1124 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 928/1000
# 32/32 - 0s - loss: 0.0810 - accuracy: 0.9668 - val_loss: 0.1139 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 929/1000
# 32/32 - 0s - loss: 0.1012 - accuracy: 0.9609 - val_loss: 0.1276 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 930/1000
# 32/32 - 0s - loss: 0.1032 - accuracy: 0.9639 - val_loss: 0.0994 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 931/1000
# 32/32 - 0s - loss: 0.0862 - accuracy: 0.9688 - val_loss: 0.1017 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 932/1000
# 32/32 - 0s - loss: 0.0826 - accuracy: 0.9678 - val_loss: 0.0876 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 933/1000
# 32/32 - 0s - loss: 0.0835 - accuracy: 0.9727 - val_loss: 0.0881 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 934/1000
# 32/32 - 0s - loss: 0.0843 - accuracy: 0.9658 - val_loss: 0.1055 - val_accuracy: 0.9531 - 45ms/epoch - 1ms/step
# Epoch 935/1000
# 32/32 - 0s - loss: 0.0937 - accuracy: 0.9619 - val_loss: 0.0857 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 936/1000
# 32/32 - 0s - loss: 0.0894 - accuracy: 0.9658 - val_loss: 0.1065 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 937/1000
# 32/32 - 0s - loss: 0.0876 - accuracy: 0.9727 - val_loss: 0.1170 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 938/1000
# 32/32 - 0s - loss: 0.0868 - accuracy: 0.9609 - val_loss: 0.0923 - val_accuracy: 0.9570 - 48ms/epoch - 2ms/step
# Epoch 939/1000
# 32/32 - 0s - loss: 0.0911 - accuracy: 0.9590 - val_loss: 0.1414 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 940/1000
# 32/32 - 0s - loss: 0.1054 - accuracy: 0.9590 - val_loss: 0.1579 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 941/1000
# 32/32 - 0s - loss: 0.0956 - accuracy: 0.9619 - val_loss: 0.0970 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 942/1000
# 32/32 - 0s - loss: 0.0870 - accuracy: 0.9629 - val_loss: 0.0961 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 943/1000
# 32/32 - 0s - loss: 0.0880 - accuracy: 0.9668 - val_loss: 0.1738 - val_accuracy: 0.9414 - 60ms/epoch - 2ms/step
# Epoch 944/1000
# 32/32 - 0s - loss: 0.0936 - accuracy: 0.9639 - val_loss: 0.0907 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 945/1000
# 32/32 - 0s - loss: 0.0883 - accuracy: 0.9668 - val_loss: 0.0946 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 946/1000
# 32/32 - 0s - loss: 0.0867 - accuracy: 0.9668 - val_loss: 0.1049 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 947/1000
# 32/32 - 0s - loss: 0.0924 - accuracy: 0.9639 - val_loss: 0.1257 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 948/1000
# 32/32 - 0s - loss: 0.0924 - accuracy: 0.9658 - val_loss: 0.1217 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 949/1000
# 32/32 - 0s - loss: 0.0912 - accuracy: 0.9619 - val_loss: 0.0875 - val_accuracy: 0.9648 - 45ms/epoch - 1ms/step
# Epoch 950/1000
# 32/32 - 0s - loss: 0.0881 - accuracy: 0.9688 - val_loss: 0.1049 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 951/1000
# 32/32 - 0s - loss: 0.0867 - accuracy: 0.9648 - val_loss: 0.1051 - val_accuracy: 0.9570 - 48ms/epoch - 1ms/step
# Epoch 952/1000
# 32/32 - 0s - loss: 0.0869 - accuracy: 0.9668 - val_loss: 0.0948 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 953/1000
# 32/32 - 0s - loss: 0.0864 - accuracy: 0.9678 - val_loss: 0.0981 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 954/1000
# 32/32 - 0s - loss: 0.0815 - accuracy: 0.9697 - val_loss: 0.1452 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 955/1000
# 32/32 - 0s - loss: 0.0926 - accuracy: 0.9648 - val_loss: 0.1035 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 956/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9639 - val_loss: 0.1103 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 957/1000
# 32/32 - 0s - loss: 0.0860 - accuracy: 0.9678 - val_loss: 0.1438 - val_accuracy: 0.9453 - 46ms/epoch - 1ms/step
# Epoch 958/1000
# 32/32 - 0s - loss: 0.0854 - accuracy: 0.9688 - val_loss: 0.1000 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 959/1000
# 32/32 - 0s - loss: 0.0917 - accuracy: 0.9668 - val_loss: 0.1349 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 960/1000
# 32/32 - 0s - loss: 0.0931 - accuracy: 0.9648 - val_loss: 0.1164 - val_accuracy: 0.9453 - 45ms/epoch - 1ms/step
# Epoch 961/1000
# 32/32 - 0s - loss: 0.0918 - accuracy: 0.9658 - val_loss: 0.1381 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 962/1000
# 32/32 - 0s - loss: 0.0983 - accuracy: 0.9590 - val_loss: 0.0988 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 963/1000
# 32/32 - 0s - loss: 0.0875 - accuracy: 0.9678 - val_loss: 0.0933 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 964/1000
# 32/32 - 0s - loss: 0.0893 - accuracy: 0.9619 - val_loss: 0.0983 - val_accuracy: 0.9570 - 46ms/epoch - 1ms/step
# Epoch 965/1000
# 32/32 - 0s - loss: 0.0910 - accuracy: 0.9658 - val_loss: 0.1240 - val_accuracy: 0.9453 - 58ms/epoch - 2ms/step
# Epoch 966/1000
# 32/32 - 0s - loss: 0.0826 - accuracy: 0.9727 - val_loss: 0.0977 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 967/1000
# 32/32 - 0s - loss: 0.0841 - accuracy: 0.9629 - val_loss: 0.1139 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 968/1000
# 32/32 - 0s - loss: 0.0874 - accuracy: 0.9639 - val_loss: 0.0993 - val_accuracy: 0.9688 - 46ms/epoch - 1ms/step
# Epoch 969/1000
# 32/32 - 0s - loss: 0.0849 - accuracy: 0.9668 - val_loss: 0.1416 - val_accuracy: 0.9375 - 47ms/epoch - 1ms/step
# Epoch 970/1000
# 32/32 - 0s - loss: 0.0904 - accuracy: 0.9668 - val_loss: 0.1223 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 971/1000
# 32/32 - 0s - loss: 0.1001 - accuracy: 0.9561 - val_loss: 0.1413 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 972/1000
# 32/32 - 0s - loss: 0.0978 - accuracy: 0.9600 - val_loss: 0.1102 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 973/1000
# 32/32 - 0s - loss: 0.0824 - accuracy: 0.9678 - val_loss: 0.0927 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 974/1000
# 32/32 - 0s - loss: 0.0903 - accuracy: 0.9648 - val_loss: 0.0984 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 975/1000
# 32/32 - 0s - loss: 0.0847 - accuracy: 0.9648 - val_loss: 0.1005 - val_accuracy: 0.9648 - 47ms/epoch - 1ms/step
# Epoch 976/1000
# 32/32 - 0s - loss: 0.0889 - accuracy: 0.9658 - val_loss: 0.1480 - val_accuracy: 0.9414 - 49ms/epoch - 2ms/step
# Epoch 977/1000
# 32/32 - 0s - loss: 0.1108 - accuracy: 0.9600 - val_loss: 0.0895 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 978/1000
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9619 - val_loss: 0.0889 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 979/1000
# 32/32 - 0s - loss: 0.0835 - accuracy: 0.9668 - val_loss: 0.1092 - val_accuracy: 0.9570 - 45ms/epoch - 1ms/step
# Epoch 980/1000
# 32/32 - 0s - loss: 0.0807 - accuracy: 0.9688 - val_loss: 0.0955 - val_accuracy: 0.9609 - 45ms/epoch - 1ms/step
# Epoch 981/1000
# 32/32 - 0s - loss: 0.0826 - accuracy: 0.9707 - val_loss: 0.1233 - val_accuracy: 0.9492 - 46ms/epoch - 1ms/step
# Epoch 982/1000
# 32/32 - 0s - loss: 0.0823 - accuracy: 0.9648 - val_loss: 0.1091 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 983/1000
# 32/32 - 0s - loss: 0.0863 - accuracy: 0.9639 - val_loss: 0.1058 - val_accuracy: 0.9570 - 47ms/epoch - 1ms/step
# Epoch 984/1000
# 32/32 - 0s - loss: 0.0864 - accuracy: 0.9629 - val_loss: 0.0979 - val_accuracy: 0.9688 - 47ms/epoch - 1ms/step
# Epoch 985/1000
# 32/32 - 0s - loss: 0.0863 - accuracy: 0.9688 - val_loss: 0.0942 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 986/1000
# 32/32 - 0s - loss: 0.0816 - accuracy: 0.9688 - val_loss: 0.0997 - val_accuracy: 0.9492 - 47ms/epoch - 1ms/step
# Epoch 987/1000
# 32/32 - 0s - loss: 0.0848 - accuracy: 0.9717 - val_loss: 0.0954 - val_accuracy: 0.9531 - 48ms/epoch - 1ms/step
# Epoch 988/1000
# 32/32 - 0s - loss: 0.0946 - accuracy: 0.9600 - val_loss: 0.1067 - val_accuracy: 0.9648 - 61ms/epoch - 2ms/step
# Epoch 989/1000
# 32/32 - 0s - loss: 0.0825 - accuracy: 0.9697 - val_loss: 0.1190 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 990/1000
# 32/32 - 0s - loss: 0.0811 - accuracy: 0.9658 - val_loss: 0.1064 - val_accuracy: 0.9531 - 46ms/epoch - 1ms/step
# Epoch 991/1000
# 32/32 - 0s - loss: 0.0901 - accuracy: 0.9658 - val_loss: 0.1196 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 992/1000
# 32/32 - 0s - loss: 0.0883 - accuracy: 0.9639 - val_loss: 0.1239 - val_accuracy: 0.9492 - 45ms/epoch - 1ms/step
# Epoch 993/1000
# 32/32 - 0s - loss: 0.0897 - accuracy: 0.9629 - val_loss: 0.1196 - val_accuracy: 0.9414 - 46ms/epoch - 1ms/step
# Epoch 994/1000
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9590 - val_loss: 0.1064 - val_accuracy: 0.9609 - 46ms/epoch - 1ms/step
# Epoch 995/1000
# 32/32 - 0s - loss: 0.0885 - accuracy: 0.9668 - val_loss: 0.1010 - val_accuracy: 0.9531 - 47ms/epoch - 1ms/step
# Epoch 996/1000
# 32/32 - 0s - loss: 0.0943 - accuracy: 0.9648 - val_loss: 0.0925 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 997/1000
# 32/32 - 0s - loss: 0.0806 - accuracy: 0.9648 - val_loss: 0.0995 - val_accuracy: 0.9648 - 46ms/epoch - 1ms/step
# Epoch 998/1000
# 32/32 - 0s - loss: 0.0942 - accuracy: 0.9619 - val_loss: 0.1105 - val_accuracy: 0.9688 - 48ms/epoch - 1ms/step
# Epoch 999/1000
# 32/32 - 0s - loss: 0.0907 - accuracy: 0.9639 - val_loss: 0.1064 - val_accuracy: 0.9609 - 47ms/epoch - 1ms/step
# Epoch 1000/1000
# 32/32 - 0s - loss: 0.0786 - accuracy: 0.9668 - val_loss: 0.0924 - val_accuracy: 0.9688 - 50ms/epoch - 2ms/step

# %%
tf_model.evaluate(X_test,  y_test, verbose = 2 )
# Out:
# 8/8 - 0s - loss: 0.0924 - accuracy: 0.9688 - 17ms/epoch - 2ms/step
# [0.09244771301746368, 0.96875]

# %%
# for probabilities add last layer as Softmax layer
probability_model = tf.keras.Sequential([tf_model,
                                         tf.keras.layers.Softmax()
                                        ])

# %%
y_pred = probability_model(X_test).numpy().argmax(axis = 1)

print('Accuracy score on Test Data :', accuracy_score(y_test, y_pred))
# Out:
# Accuracy score on Test Data : 0.96875

# %%
res_df = pd.DataFrame(history.history)

fn_plot_hist(res_df)
