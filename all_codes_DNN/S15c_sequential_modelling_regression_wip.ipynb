# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 15c
#
# ### Using artificial data
#
# ## Sequential Modeling Regression
# </p><img src='../../images/prasami_color_tutorials_small.png' style = 'width:400px;' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf
# Out:
# 2023-11-28 12:49:02.945824: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 12:49:02.945856: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 12:49:02.946957: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 12:49:02.952737: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 12:49:03.604305: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

EPOCHS = 100

BATCH_SIZE = 64
# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (12,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Basic Hygiene

# %%
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2023-11-28 12:49:04.247623: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-28 12:49:04.277216: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-28 12:49:04.277459: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
def fn_plot_hist(hist_df):
    
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)

    ax = axes[0]

    y1 = hist_df.columns[0]
    y2 = hist_df.columns[2]
    hist_df.plot(y = [y1, y2], ax = ax, colormap=CMAP)

    lossmin = hist_df[y1].min()

    testmin = hist_df[y2].min()

    # little beautification
    txtstr = "Min Loss: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(lossmin,
                                                                            testmin) #text to plot

    # place a text box in upper left in axes coords

    ax.text(0.4, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    ax.set_xlabel("Epochs")

    ax.set_ylabel(y1.capitalize())

    ax.grid();

    ax = axes[1]
    
    y1 = hist_df.columns[1]
    y2 = hist_df.columns[3]
    hist_df.plot( y = [y1, y2], ax = ax, colormap=CMAP)
    
    # little beautification
    accmax = hist_df[y1].min()
    testmax = hist_df[y2].min()
    txtstr = "Min MAE: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(accmax,
                                                                                testmax) #text to plot

    # place a text box in upper left in axes coords

    ax.text(0.4, 0.5, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.grid();
    plt.tight_layout()

# %% [markdown]
# ## Create Some Regression data

# %%
start = -2.1
end = 2.1

### Training data

delta = 0.001

X_train = np.arange(start, end+ delta,delta)
y_rnd = np.random.rand(X_train.shape[0]) - 0.5
y_true =   2* np.square(X_train) + 2 * np.sin(np.pi*X_train)
y_train = y_true + y_rnd* 2

### Test data
X_test = np.arange(start, end+ delta, delta * 10 )
y_rnd = np.random.rand(X_test.shape[0])- 0.5
y_true_test =   2* np.square(X_test) + 2 * np.sin(np.pi*X_test)
y_test = y_true_test  + y_rnd* 2

# %%
X_train.shape
# Out:
# (4201,)

# %%
4201/64
# Out:
# 65.640625

# %%
num_examples = BATCH_SIZE * 65

X_train = X_train[:num_examples]
y_train = y_train[:num_examples]
y_true = y_true[:num_examples]

# %%
X_train.shape
# Out:
# (4160,)

# %%
X_train.max(), X_test.max()
# Out:
# (2.0589999999995423, 2.0999999999999104)

# %%
start = -2
end = 2
delta_train = 0.01

fig, axes = plt.subplots(1, 2, figsize =(15,5))

ax = axes[0]
ax.plot(X_train, y_train, 'b*', markersize=2, label = 'Train')
ax.plot(X_train,  y_true, c = 'k', linewidth=2, label = 'True')
ax.axhline(0, c = 'k')
ax.axvline(0, c = 'k')
ax.grid()
ax.legend()

ax = axes[1]
ax.plot(X_test, y_test, 'g*', markersize=2, label = 'Test')
ax.plot(X_test,  y_true_test, c = 'k', linewidth=2, label = 'True')
ax.axhline(0, c = 'k')
ax.axvline(0, c = 'k')
ax.grid()
ax.legend();

# %%
# What shape of Input layer?
num_features = 1

#initializer = tf.keras.initializers.HeNormal(seed = RANDOM_STATE)

# Define Model

# Define the input layer
input_layer = tf.keras.layers.Input(shape=(1,))  # Assuming input shape is (784,)

# Add a hidden layer with 128 neurons and ReLU activation
hidden_layer = tf.keras.layers.Dense(128, activation='relu')(input_layer)

# Add another hidden layer with 64 neurons and ReLU activation
hidden_layer = tf.keras.layers.Dense(64, activation='relu')(hidden_layer)

# Add the output layer with 10 neurons (for a classification task) and softmax activation
output_layer = tf.keras.layers.Dense(1)(hidden_layer)

# Create the model by specifying the input and output layers
model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

# %%
# Compile the model with a specific optimizer, loss function, and metrics

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
# fit the model
history = model.fit(X_train, y_train, 
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    epochs=EPOCHS, 
                    verbose=2)
# Out:
# Epoch 1/100
# 2023-11-28 12:54:39.085425: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-11-28 12:54:39.337381: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8a6e3ba2d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-28 12:54:39.337404: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-11-28 12:54:39.340987: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-28 12:54:39.354064: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1701156279.403586   92976 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 65/65 - 1s - loss: 9.2707 - mae: 2.3357 - val_loss: 3.9226 - val_mae: 1.6657 - 1s/epoch - 17ms/step
# Epoch 2/100
# 65/65 - 0s - loss: 3.2033 - mae: 1.4686 - val_loss: 2.6950 - val_mae: 1.3603 - 88ms/epoch - 1ms/step
# Epoch 3/100
# 65/65 - 0s - loss: 2.1071 - mae: 1.1856 - val_loss: 1.7628 - val_mae: 1.0817 - 88ms/epoch - 1ms/step
# Epoch 4/100
# 65/65 - 0s - loss: 1.3979 - mae: 0.9515 - val_loss: 1.3590 - val_mae: 0.9137 - 87ms/epoch - 1ms/step
# Epoch 5/100
# 65/65 - 0s - loss: 1.1470 - mae: 0.8374 - val_loss: 1.2473 - val_mae: 0.8672 - 84ms/epoch - 1ms/step
# Epoch 6/100
# 65/65 - 0s - loss: 1.0784 - mae: 0.8082 - val_loss: 1.2126 - val_mae: 0.8545 - 87ms/epoch - 1ms/step
# Epoch 7/100
# 65/65 - 0s - loss: 1.0488 - mae: 0.7982 - val_loss: 1.2041 - val_mae: 0.8406 - 87ms/epoch - 1ms/step
# Epoch 8/100
# 65/65 - 0s - loss: 1.0122 - mae: 0.7822 - val_loss: 1.1290 - val_mae: 0.8240 - 87ms/epoch - 1ms/step
# Epoch 9/100
# 65/65 - 0s - loss: 0.9674 - mae: 0.7666 - val_loss: 1.0791 - val_mae: 0.8173 - 85ms/epoch - 1ms/step
# Epoch 10/100
# 65/65 - 0s - loss: 0.9094 - mae: 0.7475 - val_loss: 1.0103 - val_mae: 0.7852 - 89ms/epoch - 1ms/step
# Epoch 11/100
# 65/65 - 0s - loss: 0.8549 - mae: 0.7262 - val_loss: 0.9254 - val_mae: 0.7626 - 86ms/epoch - 1ms/step
# Epoch 12/100
# 65/65 - 0s - loss: 0.7959 - mae: 0.7034 - val_loss: 0.8750 - val_mae: 0.7348 - 86ms/epoch - 1ms/step
# Epoch 13/100
# 65/65 - 0s - loss: 0.7301 - mae: 0.6799 - val_loss: 0.7797 - val_mae: 0.7079 - 89ms/epoch - 1ms/step
# Epoch 14/100
# 65/65 - 0s - loss: 0.6690 - mae: 0.6551 - val_loss: 0.7092 - val_mae: 0.6772 - 84ms/epoch - 1ms/step
# Epoch 15/100
# 65/65 - 0s - loss: 0.6089 - mae: 0.6292 - val_loss: 0.6475 - val_mae: 0.6510 - 84ms/epoch - 1ms/step
# Epoch 16/100
# 65/65 - 0s - loss: 0.5600 - mae: 0.6070 - val_loss: 0.5862 - val_mae: 0.6264 - 86ms/epoch - 1ms/step
# Epoch 17/100
# 65/65 - 0s - loss: 0.5129 - mae: 0.5864 - val_loss: 0.5349 - val_mae: 0.6051 - 89ms/epoch - 1ms/step
# Epoch 18/100
# 65/65 - 0s - loss: 0.4743 - mae: 0.5677 - val_loss: 0.4962 - val_mae: 0.5831 - 85ms/epoch - 1ms/step
# Epoch 19/100
# 65/65 - 0s - loss: 0.4498 - mae: 0.5565 - val_loss: 0.4719 - val_mae: 0.5722 - 86ms/epoch - 1ms/step
# Epoch 20/100
# 65/65 - 0s - loss: 0.4288 - mae: 0.5474 - val_loss: 0.4460 - val_mae: 0.5632 - 85ms/epoch - 1ms/step
# Epoch 21/100
# 65/65 - 0s - loss: 0.4087 - mae: 0.5369 - val_loss: 0.4247 - val_mae: 0.5514 - 87ms/epoch - 1ms/step
# Epoch 22/100
# 65/65 - 0s - loss: 0.3987 - mae: 0.5331 - val_loss: 0.4211 - val_mae: 0.5517 - 87ms/epoch - 1ms/step
# Epoch 23/100
# 65/65 - 0s - loss: 0.3853 - mae: 0.5271 - val_loss: 0.4064 - val_mae: 0.5417 - 85ms/epoch - 1ms/step
# Epoch 24/100
# 65/65 - 0s - loss: 0.3853 - mae: 0.5255 - val_loss: 0.4005 - val_mae: 0.5393 - 86ms/epoch - 1ms/step
# Epoch 25/100
# 65/65 - 0s - loss: 0.3712 - mae: 0.5198 - val_loss: 0.3949 - val_mae: 0.5351 - 86ms/epoch - 1ms/step
# Epoch 26/100
# 65/65 - 0s - loss: 0.3710 - mae: 0.5182 - val_loss: 0.3952 - val_mae: 0.5320 - 85ms/epoch - 1ms/step
# Epoch 27/100
# 65/65 - 0s - loss: 0.3628 - mae: 0.5154 - val_loss: 0.3841 - val_mae: 0.5299 - 85ms/epoch - 1ms/step
# Epoch 28/100
# 65/65 - 0s - loss: 0.3614 - mae: 0.5147 - val_loss: 0.3815 - val_mae: 0.5301 - 88ms/epoch - 1ms/step
# Epoch 29/100
# 65/65 - 0s - loss: 0.3587 - mae: 0.5142 - val_loss: 0.3782 - val_mae: 0.5300 - 84ms/epoch - 1ms/step
# Epoch 30/100
# 65/65 - 0s - loss: 0.3563 - mae: 0.5131 - val_loss: 0.3782 - val_mae: 0.5282 - 86ms/epoch - 1ms/step
# Epoch 31/100
# 65/65 - 0s - loss: 0.3533 - mae: 0.5111 - val_loss: 0.3772 - val_mae: 0.5263 - 85ms/epoch - 1ms/step
# Epoch 32/100
# 65/65 - 0s - loss: 0.3589 - mae: 0.5135 - val_loss: 0.3807 - val_mae: 0.5274 - 84ms/epoch - 1ms/step
# Epoch 33/100
# 65/65 - 0s - loss: 0.3516 - mae: 0.5107 - val_loss: 0.3753 - val_mae: 0.5287 - 87ms/epoch - 1ms/step
# Epoch 34/100
# 65/65 - 0s - loss: 0.3527 - mae: 0.5107 - val_loss: 0.3733 - val_mae: 0.5281 - 89ms/epoch - 1ms/step
# Epoch 35/100
# 65/65 - 0s - loss: 0.3505 - mae: 0.5086 - val_loss: 0.3719 - val_mae: 0.5251 - 101ms/epoch - 2ms/step
# Epoch 36/100
# 65/65 - 0s - loss: 0.3518 - mae: 0.5103 - val_loss: 0.3729 - val_mae: 0.5260 - 85ms/epoch - 1ms/step
# Epoch 37/100
# 65/65 - 0s - loss: 0.3492 - mae: 0.5078 - val_loss: 0.3713 - val_mae: 0.5223 - 88ms/epoch - 1ms/step
# Epoch 38/100
# 65/65 - 0s - loss: 0.3636 - mae: 0.5141 - val_loss: 0.3702 - val_mae: 0.5244 - 88ms/epoch - 1ms/step
# Epoch 39/100
# 65/65 - 0s - loss: 0.3518 - mae: 0.5097 - val_loss: 0.3849 - val_mae: 0.5295 - 87ms/epoch - 1ms/step
# Epoch 40/100
# 65/65 - 0s - loss: 0.3553 - mae: 0.5120 - val_loss: 0.3671 - val_mae: 0.5247 - 85ms/epoch - 1ms/step
# Epoch 41/100
# 65/65 - 0s - loss: 0.3489 - mae: 0.5087 - val_loss: 0.3761 - val_mae: 0.5298 - 85ms/epoch - 1ms/step
# Epoch 42/100
# 65/65 - 0s - loss: 0.3467 - mae: 0.5060 - val_loss: 0.3622 - val_mae: 0.5204 - 87ms/epoch - 1ms/step
# Epoch 43/100
# 65/65 - 0s - loss: 0.3465 - mae: 0.5081 - val_loss: 0.3631 - val_mae: 0.5230 - 86ms/epoch - 1ms/step
# Epoch 44/100
# 65/65 - 0s - loss: 0.3472 - mae: 0.5084 - val_loss: 0.3790 - val_mae: 0.5282 - 87ms/epoch - 1ms/step
# Epoch 45/100
# 65/65 - 0s - loss: 0.3468 - mae: 0.5086 - val_loss: 0.3697 - val_mae: 0.5233 - 89ms/epoch - 1ms/step
# Epoch 46/100
# 65/65 - 0s - loss: 0.3429 - mae: 0.5051 - val_loss: 0.3743 - val_mae: 0.5253 - 106ms/epoch - 2ms/step
# Epoch 47/100
# 65/65 - 0s - loss: 0.3457 - mae: 0.5081 - val_loss: 0.3711 - val_mae: 0.5250 - 101ms/epoch - 2ms/step
# Epoch 48/100
# 65/65 - 0s - loss: 0.3460 - mae: 0.5065 - val_loss: 0.3619 - val_mae: 0.5215 - 91ms/epoch - 1ms/step
# Epoch 49/100
# 65/65 - 0s - loss: 0.3446 - mae: 0.5061 - val_loss: 0.3709 - val_mae: 0.5251 - 86ms/epoch - 1ms/step
# Epoch 50/100
# 65/65 - 0s - loss: 0.3474 - mae: 0.5071 - val_loss: 0.3621 - val_mae: 0.5205 - 88ms/epoch - 1ms/step
# Epoch 51/100
# 65/65 - 0s - loss: 0.3443 - mae: 0.5061 - val_loss: 0.3683 - val_mae: 0.5211 - 87ms/epoch - 1ms/step
# Epoch 52/100
# 65/65 - 0s - loss: 0.3496 - mae: 0.5106 - val_loss: 0.3739 - val_mae: 0.5268 - 98ms/epoch - 2ms/step
# Epoch 53/100
# 65/65 - 0s - loss: 0.3453 - mae: 0.5076 - val_loss: 0.3698 - val_mae: 0.5255 - 102ms/epoch - 2ms/step
# Epoch 54/100
# 65/65 - 0s - loss: 0.3458 - mae: 0.5074 - val_loss: 0.3647 - val_mae: 0.5229 - 93ms/epoch - 1ms/step
# Epoch 55/100
# 65/65 - 0s - loss: 0.3449 - mae: 0.5063 - val_loss: 0.3676 - val_mae: 0.5226 - 84ms/epoch - 1ms/step
# Epoch 56/100
# 65/65 - 0s - loss: 0.3458 - mae: 0.5086 - val_loss: 0.3600 - val_mae: 0.5198 - 105ms/epoch - 2ms/step
# Epoch 57/100
# 65/65 - 0s - loss: 0.3444 - mae: 0.5065 - val_loss: 0.3624 - val_mae: 0.5230 - 97ms/epoch - 1ms/step
# Epoch 58/100
# 65/65 - 0s - loss: 0.3437 - mae: 0.5063 - val_loss: 0.3600 - val_mae: 0.5219 - 85ms/epoch - 1ms/step
# Epoch 59/100
# 65/65 - 0s - loss: 0.3475 - mae: 0.5084 - val_loss: 0.3671 - val_mae: 0.5270 - 89ms/epoch - 1ms/step
# Epoch 60/100
# 65/65 - 0s - loss: 0.3482 - mae: 0.5092 - val_loss: 0.3623 - val_mae: 0.5235 - 88ms/epoch - 1ms/step
# Epoch 61/100
# 65/65 - 0s - loss: 0.3491 - mae: 0.5093 - val_loss: 0.3805 - val_mae: 0.5340 - 88ms/epoch - 1ms/step
# Epoch 62/100
# 65/65 - 0s - loss: 0.3482 - mae: 0.5090 - val_loss: 0.3687 - val_mae: 0.5221 - 94ms/epoch - 1ms/step
# Epoch 63/100
# 65/65 - 0s - loss: 0.3429 - mae: 0.5046 - val_loss: 0.3605 - val_mae: 0.5211 - 90ms/epoch - 1ms/step
# Epoch 64/100
# 65/65 - 0s - loss: 0.3456 - mae: 0.5074 - val_loss: 0.3694 - val_mae: 0.5192 - 108ms/epoch - 2ms/step
# Epoch 65/100
# 65/65 - 0s - loss: 0.3447 - mae: 0.5060 - val_loss: 0.3648 - val_mae: 0.5245 - 102ms/epoch - 2ms/step
# Epoch 66/100
# 65/65 - 0s - loss: 0.3484 - mae: 0.5071 - val_loss: 0.3644 - val_mae: 0.5197 - 88ms/epoch - 1ms/step
# Epoch 67/100
# 65/65 - 0s - loss: 0.3460 - mae: 0.5071 - val_loss: 0.3578 - val_mae: 0.5197 - 86ms/epoch - 1ms/step
# Epoch 68/100
# 65/65 - 0s - loss: 0.3469 - mae: 0.5085 - val_loss: 0.3721 - val_mae: 0.5214 - 88ms/epoch - 1ms/step
# Epoch 69/100
# 65/65 - 0s - loss: 0.3428 - mae: 0.5060 - val_loss: 0.3705 - val_mae: 0.5240 - 122ms/epoch - 2ms/step
# Epoch 70/100
# 65/65 - 0s - loss: 0.3499 - mae: 0.5095 - val_loss: 0.3609 - val_mae: 0.5208 - 100ms/epoch - 2ms/step
# Epoch 71/100
# 65/65 - 0s - loss: 0.3453 - mae: 0.5075 - val_loss: 0.3808 - val_mae: 0.5248 - 100ms/epoch - 2ms/step
# Epoch 72/100
# 65/65 - 0s - loss: 0.3431 - mae: 0.5056 - val_loss: 0.3632 - val_mae: 0.5219 - 84ms/epoch - 1ms/step
# Epoch 73/100
# 65/65 - 0s - loss: 0.3443 - mae: 0.5055 - val_loss: 0.3653 - val_mae: 0.5173 - 85ms/epoch - 1ms/step
# Epoch 74/100
# 65/65 - 0s - loss: 0.3474 - mae: 0.5075 - val_loss: 0.3553 - val_mae: 0.5179 - 89ms/epoch - 1ms/step
# Epoch 75/100
# 65/65 - 0s - loss: 0.3418 - mae: 0.5051 - val_loss: 0.3594 - val_mae: 0.5177 - 102ms/epoch - 2ms/step
# Epoch 76/100
# 65/65 - 0s - loss: 0.3464 - mae: 0.5085 - val_loss: 0.3571 - val_mae: 0.5192 - 98ms/epoch - 2ms/step
# Epoch 77/100
# 65/65 - 0s - loss: 0.3481 - mae: 0.5088 - val_loss: 0.3620 - val_mae: 0.5183 - 95ms/epoch - 1ms/step
# Epoch 78/100
# 65/65 - 0s - loss: 0.3457 - mae: 0.5088 - val_loss: 0.3699 - val_mae: 0.5297 - 84ms/epoch - 1ms/step
# Epoch 79/100
# 65/65 - 0s - loss: 0.3451 - mae: 0.5056 - val_loss: 0.3623 - val_mae: 0.5202 - 104ms/epoch - 2ms/step
# Epoch 80/100
# 65/65 - 0s - loss: 0.3441 - mae: 0.5072 - val_loss: 0.3623 - val_mae: 0.5197 - 97ms/epoch - 1ms/step
# Epoch 81/100
# 65/65 - 0s - loss: 0.3426 - mae: 0.5054 - val_loss: 0.3657 - val_mae: 0.5226 - 92ms/epoch - 1ms/step
# Epoch 82/100
# 65/65 - 0s - loss: 0.3474 - mae: 0.5084 - val_loss: 0.3610 - val_mae: 0.5191 - 85ms/epoch - 1ms/step
# Epoch 83/100
# 65/65 - 0s - loss: 0.3457 - mae: 0.5078 - val_loss: 0.3678 - val_mae: 0.5247 - 88ms/epoch - 1ms/step
# Epoch 84/100
# 65/65 - 0s - loss: 0.3472 - mae: 0.5073 - val_loss: 0.3613 - val_mae: 0.5188 - 101ms/epoch - 2ms/step
# Epoch 85/100
# 65/65 - 0s - loss: 0.3501 - mae: 0.5095 - val_loss: 0.4002 - val_mae: 0.5431 - 100ms/epoch - 2ms/step
# Epoch 86/100
# 65/65 - 0s - loss: 0.3416 - mae: 0.5040 - val_loss: 0.3668 - val_mae: 0.5240 - 87ms/epoch - 1ms/step
# Epoch 87/100
# 65/65 - 0s - loss: 0.3430 - mae: 0.5061 - val_loss: 0.3596 - val_mae: 0.5174 - 85ms/epoch - 1ms/step
# Epoch 88/100
# 65/65 - 0s - loss: 0.3433 - mae: 0.5075 - val_loss: 0.3594 - val_mae: 0.5217 - 86ms/epoch - 1ms/step
# Epoch 89/100
# 65/65 - 0s - loss: 0.3481 - mae: 0.5100 - val_loss: 0.3573 - val_mae: 0.5189 - 84ms/epoch - 1ms/step
# Epoch 90/100
# 65/65 - 0s - loss: 0.3510 - mae: 0.5102 - val_loss: 0.4119 - val_mae: 0.5423 - 87ms/epoch - 1ms/step
# Epoch 91/100
# 65/65 - 0s - loss: 0.3455 - mae: 0.5070 - val_loss: 0.3604 - val_mae: 0.5206 - 86ms/epoch - 1ms/step
# Epoch 92/100
# 65/65 - 0s - loss: 0.3472 - mae: 0.5089 - val_loss: 0.3695 - val_mae: 0.5221 - 88ms/epoch - 1ms/step
# Epoch 93/100
# 65/65 - 0s - loss: 0.3435 - mae: 0.5063 - val_loss: 0.3614 - val_mae: 0.5194 - 88ms/epoch - 1ms/step
# Epoch 94/100
# 65/65 - 0s - loss: 0.3476 - mae: 0.5087 - val_loss: 0.3651 - val_mae: 0.5212 - 86ms/epoch - 1ms/step
# Epoch 95/100
# 65/65 - 0s - loss: 0.3424 - mae: 0.5055 - val_loss: 0.3581 - val_mae: 0.5166 - 88ms/epoch - 1ms/step
# Epoch 96/100
# 65/65 - 0s - loss: 0.3439 - mae: 0.5063 - val_loss: 0.3621 - val_mae: 0.5212 - 85ms/epoch - 1ms/step
# Epoch 97/100
# 65/65 - 0s - loss: 0.3448 - mae: 0.5081 - val_loss: 0.3596 - val_mae: 0.5175 - 86ms/epoch - 1ms/step
# Epoch 98/100
# 65/65 - 0s - loss: 0.3453 - mae: 0.5068 - val_loss: 0.3586 - val_mae: 0.5203 - 86ms/epoch - 1ms/step
# Epoch 99/100
# 65/65 - 0s - loss: 0.3436 - mae: 0.5066 - val_loss: 0.3582 - val_mae: 0.5198 - 86ms/epoch - 1ms/step
# Epoch 100/100
# 65/65 - 0s - loss: 0.3433 - mae: 0.5065 - val_loss: 0.3570 - val_mae: 0.5186 - 96ms/epoch - 1ms/step

# %%
hist_df = pd.DataFrame(history.history)

fn_plot_hist(hist_df)

# %%
# evaluate the model
error = model.evaluate(X_test, y_test, verbose=0)

print(f'Loss: {error[0]:.3f}, MAE: {np.sqrt(error[1]):.3f}')
# Out:
# Loss: 0.357, MAE: 0.720

# %%
y_pred = model.predict(X_test)

results_df = pd.DataFrame({'pred' : y_pred[:,0], 'test' : y_test} )

results_df['y_true'] = y_true_test
# Out:
# 14/14 [==============================] - 0s 829us/step

# %%
ax = results_df.pred.plot(c = 'r', label = 'pred');
results_df.y_true.plot(c = 'k', ax = ax, label = 'true')

plt.scatter(results_df.index, results_df.test, c='DarkBlue', marker ='*', label = 'test');
ax.set_xlabel("epoch")
ax.set_ylabel("Price")
ax.grid()
plt.legend()
plt.show()

# %%
# What shape of Input layer?
num_features = 1

initializer = tf.keras.initializers.HeNormal(seed = RANDOM_STATE)

# define model
model = tf.keras.Sequential()

model.add( tf.keras.layers.Dense(128, 
                                 activation='swish', 
                                 kernel_initializer=initializer, 
                                 input_shape=(num_features,)))

model.add(tf.keras.layers.Dense(64, 
                                activation='swish', 
                                kernel_initializer=initializer))

model.add(tf.keras.layers.Dense(1))

# %%
# compile the model
model.compile(optimizer='adam', loss='mse')

# %%
# fit the model
history = model.fit(X_train, y_train, 
          batch_size = BATCH_SIZE,
          validation_data=[X_test, y_test],
          epochs=EPOCHS, 
          verbose=2)
# Out:
# Epoch 1/100
# 65/65 - 1s - loss: 2.2129 - val_loss: 1.3174 - 652ms/epoch - 10ms/step
# Epoch 2/100
# 65/65 - 0s - loss: 1.0266 - val_loss: 0.9908 - 88ms/epoch - 1ms/step
# Epoch 3/100
# 65/65 - 0s - loss: 0.8438 - val_loss: 0.8249 - 90ms/epoch - 1ms/step
# Epoch 4/100
# 65/65 - 0s - loss: 0.7291 - val_loss: 0.7610 - 87ms/epoch - 1ms/step
# Epoch 5/100
# 65/65 - 0s - loss: 0.6833 - val_loss: 0.6784 - 89ms/epoch - 1ms/step
# Epoch 6/100
# 65/65 - 0s - loss: 0.6140 - val_loss: 0.6563 - 89ms/epoch - 1ms/step
# Epoch 7/100
# 65/65 - 0s - loss: 0.6033 - val_loss: 0.6411 - 87ms/epoch - 1ms/step
# Epoch 8/100
# 65/65 - 0s - loss: 0.5870 - val_loss: 0.5755 - 92ms/epoch - 1ms/step
# Epoch 9/100
# 65/65 - 0s - loss: 0.5470 - val_loss: 0.5676 - 89ms/epoch - 1ms/step
# Epoch 10/100
# 65/65 - 0s - loss: 0.5261 - val_loss: 0.5501 - 119ms/epoch - 2ms/step
# Epoch 11/100
# 65/65 - 0s - loss: 0.4943 - val_loss: 0.5209 - 88ms/epoch - 1ms/step
# Epoch 12/100
# 65/65 - 0s - loss: 0.4905 - val_loss: 0.5110 - 86ms/epoch - 1ms/step
# Epoch 13/100
# 65/65 - 0s - loss: 0.4745 - val_loss: 0.4647 - 89ms/epoch - 1ms/step
# Epoch 14/100
# 65/65 - 0s - loss: 0.4547 - val_loss: 0.4562 - 89ms/epoch - 1ms/step
# Epoch 15/100
# 65/65 - 0s - loss: 0.4478 - val_loss: 0.5002 - 89ms/epoch - 1ms/step
# Epoch 16/100
# 65/65 - 0s - loss: 0.4574 - val_loss: 0.4387 - 87ms/epoch - 1ms/step
# Epoch 17/100
# 65/65 - 0s - loss: 0.4305 - val_loss: 0.4403 - 88ms/epoch - 1ms/step
# Epoch 18/100
# 65/65 - 0s - loss: 0.4057 - val_loss: 0.4045 - 88ms/epoch - 1ms/step
# Epoch 19/100
# 65/65 - 0s - loss: 0.4046 - val_loss: 0.4653 - 88ms/epoch - 1ms/step
# Epoch 20/100
# 65/65 - 0s - loss: 0.4034 - val_loss: 0.4187 - 95ms/epoch - 1ms/step
# Epoch 21/100
# 65/65 - 0s - loss: 0.4000 - val_loss: 0.3941 - 94ms/epoch - 1ms/step
# Epoch 22/100
# 65/65 - 0s - loss: 0.3903 - val_loss: 0.3726 - 86ms/epoch - 1ms/step
# Epoch 23/100
# 65/65 - 0s - loss: 0.3772 - val_loss: 0.3841 - 90ms/epoch - 1ms/step
# Epoch 24/100
# 65/65 - 0s - loss: 0.3815 - val_loss: 0.3937 - 87ms/epoch - 1ms/step
# Epoch 25/100
# 65/65 - 0s - loss: 0.3753 - val_loss: 0.3775 - 87ms/epoch - 1ms/step
# Epoch 26/100
# 65/65 - 0s - loss: 0.3773 - val_loss: 0.3745 - 91ms/epoch - 1ms/step
# Epoch 27/100
# 65/65 - 0s - loss: 0.3720 - val_loss: 0.3718 - 87ms/epoch - 1ms/step
# Epoch 28/100
# 65/65 - 0s - loss: 0.3591 - val_loss: 0.3747 - 88ms/epoch - 1ms/step
# Epoch 29/100
# 65/65 - 0s - loss: 0.3864 - val_loss: 0.3718 - 90ms/epoch - 1ms/step
# Epoch 30/100
# 65/65 - 0s - loss: 0.3625 - val_loss: 0.3662 - 89ms/epoch - 1ms/step
# Epoch 31/100
# 65/65 - 0s - loss: 0.3686 - val_loss: 0.3714 - 109ms/epoch - 2ms/step
# Epoch 32/100
# 65/65 - 0s - loss: 0.3658 - val_loss: 0.3667 - 89ms/epoch - 1ms/step
# Epoch 33/100
# 65/65 - 0s - loss: 0.3675 - val_loss: 0.3851 - 86ms/epoch - 1ms/step
# Epoch 34/100
# 65/65 - 0s - loss: 0.3644 - val_loss: 0.3708 - 85ms/epoch - 1ms/step
# Epoch 35/100
# 65/65 - 0s - loss: 0.3576 - val_loss: 0.3650 - 89ms/epoch - 1ms/step
# Epoch 36/100
# 65/65 - 0s - loss: 0.3783 - val_loss: 0.3561 - 86ms/epoch - 1ms/step
# Epoch 37/100
# 65/65 - 0s - loss: 0.3640 - val_loss: 0.3610 - 86ms/epoch - 1ms/step
# Epoch 38/100
# 65/65 - 0s - loss: 0.3567 - val_loss: 0.4020 - 88ms/epoch - 1ms/step
# Epoch 39/100
# 65/65 - 0s - loss: 0.3651 - val_loss: 0.3709 - 87ms/epoch - 1ms/step
# Epoch 40/100
# 65/65 - 0s - loss: 0.3795 - val_loss: 0.3995 - 85ms/epoch - 1ms/step
# Epoch 41/100
# 65/65 - 0s - loss: 0.3589 - val_loss: 0.4063 - 90ms/epoch - 1ms/step
# Epoch 42/100
# 65/65 - 0s - loss: 0.3643 - val_loss: 0.4233 - 87ms/epoch - 1ms/step
# Epoch 43/100
# 65/65 - 0s - loss: 0.3654 - val_loss: 0.3673 - 88ms/epoch - 1ms/step
# Epoch 44/100
# 65/65 - 0s - loss: 0.3566 - val_loss: 0.3752 - 83ms/epoch - 1ms/step
# Epoch 45/100
# 65/65 - 0s - loss: 0.3714 - val_loss: 0.3690 - 89ms/epoch - 1ms/step
# Epoch 46/100
# 65/65 - 0s - loss: 0.3555 - val_loss: 0.3644 - 87ms/epoch - 1ms/step
# Epoch 47/100
# 65/65 - 0s - loss: 0.3577 - val_loss: 0.4020 - 87ms/epoch - 1ms/step
# Epoch 48/100
# 65/65 - 0s - loss: 0.3808 - val_loss: 0.3754 - 87ms/epoch - 1ms/step
# Epoch 49/100
# 65/65 - 0s - loss: 0.3647 - val_loss: 0.3642 - 90ms/epoch - 1ms/step
# Epoch 50/100
# 65/65 - 0s - loss: 0.3649 - val_loss: 0.3621 - 87ms/epoch - 1ms/step
# Epoch 51/100
# 65/65 - 0s - loss: 0.3588 - val_loss: 0.3726 - 89ms/epoch - 1ms/step
# Epoch 52/100
# 65/65 - 0s - loss: 0.3592 - val_loss: 0.3723 - 100ms/epoch - 2ms/step
# Epoch 53/100
# 65/65 - 0s - loss: 0.3717 - val_loss: 0.3582 - 100ms/epoch - 2ms/step
# Epoch 54/100
# 65/65 - 0s - loss: 0.3617 - val_loss: 0.3981 - 96ms/epoch - 1ms/step
# Epoch 55/100
# 65/65 - 0s - loss: 0.3685 - val_loss: 0.3604 - 87ms/epoch - 1ms/step
# Epoch 56/100
# 65/65 - 0s - loss: 0.3718 - val_loss: 0.3823 - 97ms/epoch - 1ms/step
# Epoch 57/100
# 65/65 - 0s - loss: 0.3557 - val_loss: 0.3976 - 108ms/epoch - 2ms/step
# Epoch 58/100
# 65/65 - 0s - loss: 0.3620 - val_loss: 0.3561 - 94ms/epoch - 1ms/step
# Epoch 59/100
# 65/65 - 0s - loss: 0.3680 - val_loss: 0.4045 - 88ms/epoch - 1ms/step
# Epoch 60/100
# 65/65 - 0s - loss: 0.3663 - val_loss: 0.3856 - 99ms/epoch - 2ms/step
# Epoch 61/100
# 65/65 - 0s - loss: 0.3605 - val_loss: 0.3658 - 101ms/epoch - 2ms/step
# Epoch 62/100
# 65/65 - 0s - loss: 0.3581 - val_loss: 0.4193 - 86ms/epoch - 1ms/step
# Epoch 63/100
# 65/65 - 0s - loss: 0.3684 - val_loss: 0.3786 - 87ms/epoch - 1ms/step
# Epoch 64/100
# 65/65 - 0s - loss: 0.3545 - val_loss: 0.4577 - 103ms/epoch - 2ms/step
# Epoch 65/100
# 65/65 - 0s - loss: 0.3705 - val_loss: 0.3557 - 101ms/epoch - 2ms/step
# Epoch 66/100
# 65/65 - 0s - loss: 0.3764 - val_loss: 0.4138 - 91ms/epoch - 1ms/step
# Epoch 67/100
# 65/65 - 0s - loss: 0.3636 - val_loss: 0.3697 - 89ms/epoch - 1ms/step
# Epoch 68/100
# 65/65 - 0s - loss: 0.3564 - val_loss: 0.3637 - 92ms/epoch - 1ms/step
# Epoch 69/100
# 65/65 - 0s - loss: 0.3726 - val_loss: 0.4227 - 93ms/epoch - 1ms/step
# Epoch 70/100
# 65/65 - 0s - loss: 0.3753 - val_loss: 0.3748 - 90ms/epoch - 1ms/step
# Epoch 71/100
# 65/65 - 0s - loss: 0.3601 - val_loss: 0.4182 - 91ms/epoch - 1ms/step
# Epoch 72/100
# 65/65 - 0s - loss: 0.3574 - val_loss: 0.3582 - 88ms/epoch - 1ms/step
# Epoch 73/100
# 65/65 - 0s - loss: 0.3676 - val_loss: 0.3558 - 88ms/epoch - 1ms/step
# Epoch 74/100
# 65/65 - 0s - loss: 0.3672 - val_loss: 0.3609 - 92ms/epoch - 1ms/step
# Epoch 75/100
# 65/65 - 0s - loss: 0.3565 - val_loss: 0.3594 - 90ms/epoch - 1ms/step
# Epoch 76/100
# 65/65 - 0s - loss: 0.3564 - val_loss: 0.3625 - 90ms/epoch - 1ms/step
# Epoch 77/100
# 65/65 - 0s - loss: 0.3626 - val_loss: 0.3719 - 91ms/epoch - 1ms/step
# Epoch 78/100
# 65/65 - 0s - loss: 0.3660 - val_loss: 0.4229 - 89ms/epoch - 1ms/step
# Epoch 79/100
# 65/65 - 0s - loss: 0.3640 - val_loss: 0.3915 - 88ms/epoch - 1ms/step
# Epoch 80/100
# 65/65 - 0s - loss: 0.3639 - val_loss: 0.4018 - 85ms/epoch - 1ms/step
# Epoch 81/100
# 65/65 - 0s - loss: 0.3675 - val_loss: 0.3648 - 85ms/epoch - 1ms/step
# Epoch 82/100
# 65/65 - 0s - loss: 0.3720 - val_loss: 0.3730 - 87ms/epoch - 1ms/step
# Epoch 83/100
# 65/65 - 0s - loss: 0.3598 - val_loss: 0.3684 - 86ms/epoch - 1ms/step
# Epoch 84/100
# 65/65 - 0s - loss: 0.3593 - val_loss: 0.3599 - 86ms/epoch - 1ms/step
# Epoch 85/100
# 65/65 - 0s - loss: 0.3546 - val_loss: 0.3632 - 88ms/epoch - 1ms/step
# Epoch 86/100
# 65/65 - 0s - loss: 0.3526 - val_loss: 0.3730 - 86ms/epoch - 1ms/step
# Epoch 87/100
# 65/65 - 0s - loss: 0.3571 - val_loss: 0.3560 - 88ms/epoch - 1ms/step
# Epoch 88/100
# 65/65 - 0s - loss: 0.3633 - val_loss: 0.3726 - 102ms/epoch - 2ms/step
# Epoch 89/100
# 65/65 - 0s - loss: 0.3698 - val_loss: 0.3671 - 100ms/epoch - 2ms/step
# Epoch 90/100
# 65/65 - 0s - loss: 0.3638 - val_loss: 0.3632 - 90ms/epoch - 1ms/step
# Epoch 91/100
# 65/65 - 0s - loss: 0.3598 - val_loss: 0.3893 - 87ms/epoch - 1ms/step
# Epoch 92/100
# 65/65 - 0s - loss: 0.3615 - val_loss: 0.3650 - 89ms/epoch - 1ms/step
# Epoch 93/100
# 65/65 - 0s - loss: 0.3560 - val_loss: 0.3712 - 124ms/epoch - 2ms/step
# Epoch 94/100
# 65/65 - 0s - loss: 0.3545 - val_loss: 0.3642 - 100ms/epoch - 2ms/step
# Epoch 95/100
# 65/65 - 0s - loss: 0.3565 - val_loss: 0.3736 - 85ms/epoch - 1ms/step
# Epoch 96/100
# 65/65 - 0s - loss: 0.3549 - val_loss: 0.3954 - 98ms/epoch - 2ms/step
# Epoch 97/100
# 65/65 - 0s - loss: 0.3553 - val_loss: 0.3595 - 115ms/epoch - 2ms/step
# Epoch 98/100
# 65/65 - 0s - loss: 0.3505 - val_loss: 0.3623 - 97ms/epoch - 1ms/step
# Epoch 99/100
# 65/65 - 0s - loss: 0.3553 - val_loss: 0.3739 - 86ms/epoch - 1ms/step
# Epoch 100/100
# 65/65 - 0s - loss: 0.3623 - val_loss: 0.3732 - 86ms/epoch - 1ms/step

# %%
y_pred = model.predict(X_test)

results_df = pd.DataFrame({'pred' : y_pred[:, 0], 'test' : y_test} )

results_df['y_true'] = y_true_test
# Out:
# 14/14 [==============================] - 0s 765us/step

# %%
ax = results_df.pred.plot(c = 'r', label = 'pred');
results_df.y_true.plot(c = 'k', ax = ax, label = 'true')

plt.scatter(results_df.index, results_df.test, c='DarkBlue', marker ='*', label = 'test');
ax.set_xlabel("epoch")
ax.set_ylabel("Price")
ax.grid()
plt.legend()
plt.show()
