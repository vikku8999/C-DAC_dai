# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 19a
#
# ## Simple RNN
#
#
# <img src='../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from datetime import datetime, timedelta

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

import tensorflow as tf

# %matplotlib inline
# Out:
# 2023-12-17 15:40:38.256290: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-17 15:40:44.967245: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 15:40:44.967447: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 15:40:46.030654: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 15:40:48.613508: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-17 15:41:00.748051: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

EPOCHS = 20  # number of cycles to run
ALPHA = 0.1  # learning rate
TEST_SIZE = 0.2 # What fraction we want to keep for testing
BATCH_SIZE = 32

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (12,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }
CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Helper Function

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %% [markdown]
# ## Load Weather Data
# Source: [Kaggle](https://www.kaggle.com/muthuj7/weather-dataset)

# %%
dataFilename = 'weatherHistory.csv'
data_df = pd.read_csv(os.path.join(inpDir, dataFilename))
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
data_df.shape
# Out:
# (96453, 12)

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'], 
                                     utc=True)

# %%
temp_df = data_df[['datetime', 'Temperature (C)']]
temp_df = temp_df.sort_values('datetime', axis=0, ascending=True)
temp_df = temp_df.reset_index(drop=True)
temp_df.head()
# Out:
#                    datetime  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
temp_df = temp_df.rename({'Temperature (C)': 'temp'}, axis=1)
temp_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
# comment uncomment following lines if you want part or full dataset

#startDate = pd.to_datetime('2007-1-1', utc=True)
#endDate = pd.to_datetime('2008-1-1', utc=True)
#temp_df = temp_df[(temp_df['datetime']  >= startDate) & (temp_df['datetime']  < endDate)]

# %%
temp_df.reset_index(drop=True, inplace = True)
temp_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
temp_df.shape
# Out:
# (96453, 2)

# %% [markdown]
# ## Plotting samples

# %%
fig, ax = plt.subplots(figsize = (15,12))
temp_df.plot(x='datetime', y='temp', style=".", ax = ax);
ax.grid()

# %%
h_units = 100
input_shape = (1, 10000)

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.SimpleRNN(units = h_units, 
                                    input_shape = input_shape, 
                                    activation = 'tanh' ))

model.add(tf.keras.layers.Dense(1, activation = 'linear' ))

# %%
wax = model.get_weights()[0].shape
waa = model.get_weights()[1].shape
baa = model.get_weights()[2].shape
way = model.get_weights()[3].shape
bay = model.get_weights()[4].shape

print ('Shape of Matrix:')
print ('Wax = ', wax,'; Waa = ', waa, '; baa = ', baa,'; Way = ', way,'; bay = ', bay)
# Out:
# Shape of Matrix:
# Wax =  (10000, 100) ; Waa =  (100, 100) ; baa =  (100,) ; Way =  (100, 1) ; bay =  (1,)

# %%
temp_df
# Out:
#                        datetime      temp
# 0     2005-12-31 23:00:00+00:00  0.577778
# 1     2006-01-01 00:00:00+00:00  1.161111
# 2     2006-01-01 01:00:00+00:00  1.666667
# 3     2006-01-01 02:00:00+00:00  1.711111
# 4     2006-01-01 03:00:00+00:00  1.183333
# ...                         ...       ...
# 96448 2016-12-31 18:00:00+00:00  0.488889
# 96449 2016-12-31 19:00:00+00:00  0.072222
# 96450 2016-12-31 20:00:00+00:00 -0.233333
# 96451 2016-12-31 21:00:00+00:00 -0.472222
# 96452 2016-12-31 22:00:00+00:00 -0.677778
#
# [96453 rows x 2 columns]

# %%
time_step = 24

# %%
temp_df.shape[0]
# Out:
# 96453

# %%
y_idx = np.arange(time_step, temp_df.shape[0], time_step)
y_df = temp_df.iloc[y_idx]
y_df.head()
# Out:
#                      datetime      temp
# 24  2006-01-01 23:00:00+00:00  5.422222
# 48  2006-01-02 23:00:00+00:00  1.694444
# 72  2006-01-03 23:00:00+00:00  2.200000
# 96  2006-01-04 23:00:00+00:00  1.666667
# 120 2006-01-05 23:00:00+00:00  1.805556

# %%
y_idx
# Out:
# array([   24,    48,    72, ..., 96384, 96408, 96432])

# %%
y_df.shape, len(y_df)*time_step
# Out:
# ((4018, 2), 96432)

# %%
temp_df.shape
# Out:
# (96453, 2)

# %%
X_df = temp_df.iloc[range(len(y_df) * time_step)]

# %%
X_df['temp'].values.shape
# Out:
# (96432,)

# %%
y_df.shape
# Out:
# (4018, 2)

# %%
X = np.reshape(X_df['temp'].values, (y_df.shape[0], time_step))
X.shape
# Out:
# (4018, 24)

# %%
X = X[:, :23]
X.shape
# Out:
# (4018, 23)

# %% [markdown]
# ## Note
#
# Need to reshape the inputs into the 3D format as expected by the SimpleRNNs, namely [samples, timesteps, features].

# %%
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
X.shape
# Out:
# (4018, 23, 1)

# %%
split = int(y_df.shape[0] * (1-TEST_SIZE))
X_train = X[:split]
X_test = X[split:]
y_train = y_df['temp'].values[:split]
y_test = y_df['temp'].values[split:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3214, 23, 1), (804, 23, 1), (3214,), (804,))

# %%
h_units = 64
input_shape=(time_step-1, 1 ) # we are using one feature only.

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.SimpleRNN(units = h_units, 
                                    input_shape = input_shape, 
                                    activation = 'tanh'))

model.add(tf.keras.layers.Dense(1, activation = 'linear'))

model.compile(loss='mean_squared_error', optimizer='adam', 
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 64)                4224
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4289 (16.75 KB)
# Trainable params: 4289 (16.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,
                    epochs=EPOCHS, 
                    validation_data=(X_test, y_test),
                    batch_size= BATCH_SIZE, 
                    verbose=1)
# Out:
# Epoch 1/20
# 101/101 [==============================] - 3s 14ms/step - loss: 43.2616 - root_mean_squared_error: 6.5774 - val_loss: 8.9245 - val_root_mean_squared_error: 2.9874
# Epoch 2/20
# 101/101 [==============================] - 1s 11ms/step - loss: 9.4077 - root_mean_squared_error: 3.0672 - val_loss: 3.3523 - val_root_mean_squared_error: 1.8309
# Epoch 3/20
# 101/101 [==============================] - 1s 11ms/step - loss: 4.4475 - root_mean_squared_error: 2.1089 - val_loss: 1.7845 - val_root_mean_squared_error: 1.3359
# Epoch 4/20
# 101/101 [==============================] - 1s 11ms/step - loss: 2.6863 - root_mean_squared_error: 1.6390 - val_loss: 1.1241 - val_root_mean_squared_error: 1.0602
# Epoch 5/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.9555 - root_mean_squared_error: 1.3984 - val_loss: 0.9271 - val_root_mean_squared_error: 0.9629
# Epoch 6/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.6020 - root_mean_squared_error: 1.2657 - val_loss: 0.8535 - val_root_mean_squared_error: 0.9239
# Epoch 7/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.4112 - root_mean_squared_error: 1.1879 - val_loss: 0.8169 - val_root_mean_squared_error: 0.9038
# Epoch 8/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.3002 - root_mean_squared_error: 1.1403 - val_loss: 0.7304 - val_root_mean_squared_error: 0.8547
# Epoch 9/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.2113 - root_mean_squared_error: 1.1006 - val_loss: 0.7423 - val_root_mean_squared_error: 0.8616
# Epoch 10/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.5745 - root_mean_squared_error: 1.2548 - val_loss: 0.8287 - val_root_mean_squared_error: 0.9103
# Epoch 11/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.1393 - root_mean_squared_error: 1.0674 - val_loss: 0.7145 - val_root_mean_squared_error: 0.8453
# Epoch 12/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0934 - root_mean_squared_error: 1.0457 - val_loss: 0.6966 - val_root_mean_squared_error: 0.8346
# Epoch 13/20
# 101/101 [==============================] - 1s 10ms/step - loss: 1.0763 - root_mean_squared_error: 1.0374 - val_loss: 0.6942 - val_root_mean_squared_error: 0.8332
# Epoch 14/20
# 101/101 [==============================] - 1s 9ms/step - loss: 1.0709 - root_mean_squared_error: 1.0349 - val_loss: 0.6694 - val_root_mean_squared_error: 0.8181
# Epoch 15/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0497 - root_mean_squared_error: 1.0246 - val_loss: 0.6865 - val_root_mean_squared_error: 0.8285
# Epoch 16/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0427 - root_mean_squared_error: 1.0211 - val_loss: 0.6905 - val_root_mean_squared_error: 0.8310
# Epoch 17/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0327 - root_mean_squared_error: 1.0162 - val_loss: 0.6583 - val_root_mean_squared_error: 0.8113
# Epoch 18/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0218 - root_mean_squared_error: 1.0108 - val_loss: 0.6523 - val_root_mean_squared_error: 0.8076
# Epoch 19/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0182 - root_mean_squared_error: 1.0091 - val_loss: 0.6450 - val_root_mean_squared_error: 0.8031
# Epoch 20/20
# 101/101 [==============================] - 1s 11ms/step - loss: 1.0271 - root_mean_squared_error: 1.0135 - val_loss: 0.6823 - val_root_mean_squared_error: 0.8260

# %%
hist_df = pd.DataFrame(history.history)
hist_df = hist_df.rename({'root_mean_squared_error': 'rmse', 'val_root_mean_squared_error' : 'val_rmse'}, axis=1)


plot_tf_hist(hist_df)

# %%
# make predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
y_pred = np.append(y_train_pred, y_test_pred)
# Out:
# 101/101 [==============================] - 1s 5ms/step
# 26/26 [==============================] - 0s 5ms/step

# %%
res_df = y_df.copy()
res_df['pred'] = y_pred
res_df['datetime'] = res_df['datetime'].dt.date
res_df.head()
# Out:
#        datetime      temp      pred
# 24   2006-01-01  5.422222  5.021980
# 48   2006-01-02  1.694444  1.756498
# 72   2006-01-03  2.200000  2.017717
# 96   2006-01-04  1.666667  1.921274
# 120  2006-01-05  1.805556  2.400314

# %%
res_df.tail()
# Out:
#          datetime      temp      pred
# 96336  2016-12-27 -1.627778 -1.445447
# 96360  2016-12-28 -1.677778 -1.494090
# 96384  2016-12-29 -1.727778 -1.542744
# 96408  2016-12-30 -1.777778 -1.590978
# 96432  2016-12-31 -1.822222 -1.633613

# %%
fig, ax = plt.subplots(figsize = (15,6))

res_df.plot(x='datetime', y=['temp','pred'], ax = ax);

ax.vlines(res_df.iloc[X_train.shape[0]]['datetime'], 
          res_df['temp'].min(), 
          res_df['temp'].max(), color = 'k', 
          linewidth=3.0, zorder=10, alpha =0.8)

ax.grid()
